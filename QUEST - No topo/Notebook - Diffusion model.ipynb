# %% [markdown]
# # Import librairies

# %%
from dolfin import*

import os
import glob

import time
import numpy as np
import pickle

from pathlib import Path
import matplotlib.pyplot as plt
from colorama import Fore, Back, Style
from CoolProp.CoolProp import PropsSI
import pyproj
from pyproj import Transformer
from mshr import Polygon, generate_mesh

from Plot_functions import*
from Auxiliary_functions import *
from Auxiliary_class import*

# %% [markdown]
# # Initialize folders

# %%
# Initialize time
time0 = time.time()

# Initialize folders for results
input_folder = "QUEST - No topo/Inputs"
output_folder = "QUEST - No topo/Outputs - Diffusion model/"
figures_output = "QUEST - No topo/Figures"

if not os.path.exists(output_folder):
    os.mkdir(output_folder)
if not os.path.exists(output_folder + "/p"):
    os.mkdir(output_folder + "/p")
else:
    for fichier in glob.glob(os.path.join(output_folder + "/p", '*')):
        os.remove(fichier)

if not os.path.exists(output_folder + "/h"):
    os.mkdir(output_folder + "/h")
else:
    for fichier in glob.glob(os.path.join(output_folder + "/h", '*')):
        os.remove(fichier)
    
if not os.path.exists(figures_output):
    os.mkdir(figures_output)

# %% [markdown]
# # Extract QUEST reservoir data

# %%
# Extract Quest data
df_PCS = pd.read_excel(os.path.join(input_folder, 'Quest, LCS, PCS.xlsx'), sheet_name='Pre-Cambrian')

# Convert GPS coordinates in UTM format
wgs84 = pyproj.CRS("EPSG:4326")
utm = pyproj.CRS("EPSG:26712")
transformer = Transformer.from_crs(wgs84, utm)
def convert_to_cartesian(longitude, latitude):
    x, y = transformer.transform(latitude, longitude)
    return x, y
df_PCS['X'], df_PCS['Y'] = zip(*df_PCS.apply(lambda row: convert_to_cartesian(-row['Long'], row['Lat']), axis=1))

# Area Of Interest coordinates
df_AOI = pd.read_csv(os.path.join(input_folder, 'AOI.csv'), sep=';', names=['Long', 'Lat'])
df_AOI['X'], df_AOI['Y'] = zip(*df_AOI.apply(lambda row: convert_to_cartesian(-row['Long'], row['Lat']), axis=1))
AOI = [[df_AOI['X'][ind], df_AOI['Y'][ind]] for ind in df_AOI.index]

x_min = np.min(df_AOI['X']) ; x_max = np.max(df_AOI['X'])
y_min = np.min(df_AOI['Y']) ; y_max = np.max(df_AOI['Y'])
xmin = x_min - 0.1*(x_max-x_min) ; xmax = x_max + 0.1*(x_max-x_min)
ymin = y_min - 0.1*(y_max-y_min) ; ymax = y_max + 0.1*(y_max-y_min)
Outline = [Point(xmin,ymin), Point(xmax,ymin), Point(xmax,ymax), Point(xmin,ymax), Point(xmin,ymin)]
Outline_array = np.array([[point[0], point[1]] for point in Outline])

# %% [markdown]
# # Model parameters

# %%
# General parameters
Temp = 70 # C # Temperature of the reservoir
Temp += 273.15 # K
p_ref = 2.0*1e7 # Pa # pressure reference (must be close to the pressure engaged in the reservoir)
p_extrem = 2.5*1e7
g = 9.81 # m.s-2
H0 = 47 # m # Thickness of the reservoir

# Depth of the reservoir. We initialize the depth using values of depth at some points.
# The field is then interpolated.
depth_points = []
depth_field = []
# Warning: depth values must be negative
for ind in df_PCS.index:
    if xmin<df_PCS['X'][ind]<xmax and ymin<df_PCS['Y'][ind]<ymax:
        depth_points.append([df_PCS['X'][ind], df_PCS['Y'][ind]])
        # depth_field.append(df_PCS['Depth_PCS'][ind]+H0)
        depth_field.append(-1400) # For flat reservoir
depth_points = np.array(depth_points)
depth_field = np.array(depth_field)

# Thickness of the reservoir. Same procedure than depth.
H_points = np.array(depth_points)
H_field = np.array([H0 for ind in range(len(H_points))])

# Reservoir physical parameters : permeability and porosity. Same procedure than thickness.
k0 = 1e-12 # m2
k_points = np.array([[xmin, xmax], [xmax, ymax], [xmin, ymin], [xmax, ymin]])
k_field = np.array([k0, k0, k0, k0])

phi0 = 0.3
phi_points = np.array([[xmin, xmax], [xmax, ymax], [xmin, ymin], [xmax, ymin]])
phi_field = np.array([phi0, phi0, phi0, phi0])

# Rock compressiblity. Has a small impact on results.
cr = 3e-11 # Pa-1

# Gas. Parameters calculated with CoolProp.
rho_g0 = PropsSI('D', 'T', Temp, 'P', p_ref, 'CO2') # kg.m-3 # density of gas
cg = PropsSI('ISOTHERMAL_COMPRESSIBILITY', 'T', Temp, 'P', p_ref, 'CO2') # Pa-1 # gas compressibility
mug0 = PropsSI('V', 'T', Temp, 'P', p_ref, 'CO2') # Pa.s # viscosity of gas
mug1 = PropsSI('V', 'T', Temp, 'P', p_extrem, 'CO2')
cvg = (mug1-mug0)/(p_extrem-p_ref)
krg = 1 # m2 # Relative permeability of gas in gas region
sg = 0.8 # saturation of gas in the gas region
def rho_g(p): return(rho_g0*(1+cg*(p-p_ref))) # Density profile
def mug(p): return(mug0*(1+cvg*(p-p_ref))) # Viscosity profile

# Water. Parameters calculated with CoolProp.
rho_w0 = PropsSI('D', 'T', Temp, 'P', p_ref, 'WATER') # kg.m-3 # density of water
cw = PropsSI('ISOTHERMAL_COMPRESSIBILITY', 'T', Temp, 'P', p_ref, 'WATER') # Pa-1 # water compressibility
muw0 = PropsSI('V', 'T', Temp, 'P', p_ref, 'WATER') # Pa.s # viscosity of water
muw1 = PropsSI('V', 'T', Temp, 'P', p_extrem, 'WATER')
cvw = (muw1-muw0)/(p_extrem-p_ref)
krw = 1 # m2 # Relative permeability of water
def rho_w(p): return(rho_w0*(1+cw*(p-p_ref))) # Density profile
def muw(p): return(muw0*(1+cvw*(p-p_ref))) # Viscosity profile

# Steps parameter
minute = 60 # s
hour = 60*minute
day = 24*hour
year = 365*day

dt = 1*minute
dt_max = 60*day
T_tot = 55*year # Simulation stopped at T_tot (even if the injection scenario is longer)

# %% [markdown]
# # Sources

# %%
Sources_g = []
# [location, [rates] in kg.s-1, [Times of operation]]
# Total amount of gas stored per year = 1.08 Mt
Rate_per_well = 1.08e9/365/24/3600/3 # convert to kg.s-1 and divide by 3
points_wells = [Point(370705.4800,5997747.3900), Point(367400,6001000), Point(376800,5994400)]
for point in points_wells:
    Sources_g.append([point, [Rate_per_well], [[5*year, 30*year]]])

sigma = 100 # m # source term standard deviation

# %% [markdown]
# # Meshgrid and model settings

# %%
# Form compiler options
parameters["form_compiler"]["optimize"]     = True
parameters["form_compiler"]["cpp_optimize"] = True
PETScOptions.set("pc_hypre_boomeramg_strong_threshold", .25)
PETScOptions.set("pc_hypre_boomeramg_truncfactor", 0.0)

# Create mesh and build function space
domain = Polygon(Outline)
Nm = 30 # define the global mesh fineness
Nhr = 1 # define the fineness of the mesh around the hydraulic radius of each well
radius1 = 2000 # The meshgrid will be refined Nhr times inside circles of radius=radius1, centered in well locations1
Nst = 4 # define the fineness of the mesh around each source
radius2 = 600 # The meshgrid will be refined Nhr times inside circles of radius=radius1, centered in well locations1
        # Source term will always be at least as accurate as hydraulic radius. We add Nst degrees of accuracy.

# mesh = create_mesh(domain, Nm, Nhr, Nst, Sources_g, sigma, T_tot, phi0, sg, rho_g0, H0)
mesh = generate_mesh(domain, Nm)
mesh = precise_mesh(mesh, points_wells, Nhr, radius1)
mesh = precise_mesh(mesh, points_wells, Nst, radius2)

print('Number of cells = '+str(mesh.num_cells()))
print(mesh.hmin())
print(mesh.hmax())

P1 = FiniteElement('Lagrange', triangle, 1)
ME = FunctionSpace(mesh, P1*P1)
ME1 = FunctionSpace(mesh, P1)
ME2=VectorFunctionSpace(mesh, "DG", 0)

fig = plt.figure(figsize=(6,6))
# plot_wells(Sources_g) # plot wells (red dots).

plot(mesh)
ax = plt.gca()
plot_AOI(ax, AOI, 'red')
plt.savefig(os.path.join(figures_output, 'QUEST_mesh_reservoir.png'), dpi=300)
# Out:
# Number of cells = 5870
# 60.9718523384101
# 3333.735283499833

# %% [markdown]
# # Initial conditions

# %% [markdown]
# #### Prepare functions and define initial conditions

# %%
# Define trial and test functions
du  = TrialFunction(ME)
v  = TestFunction(ME)

# Define functions
u   = Function(ME)  # current solution
u0  = Function(ME)  # solution from previous converged step

# Split mixed functions
dp, dh = split(du)
p,  h  = split(u)
p0, h0 = split(u0)
v_h, v_p = split(v)

# %% [markdown]
# #### Interpolate initial conditions

# %%
Coords = ME1.tabulate_dof_coordinates() # Coordinates of the mesh

# All the data are interpolated using : Radial basis function interpolation (RBF).
# Initial pressure
p_0 = 204.65e5 # Pa
p_points = np.array([[xmin, ymax], [xmax, ymax],
                     [xmin, ymin], [xmax, ymin]])
p_field = np.array([p_0, p_0,
                    p_0, p_0])
p_init = griddata(p_points, p_field, Coords, method='linear') # Linear interpolation

# Initial thickness of gas
h_0 = 0 # m
h_points = np.array([[xmin, ymax], [xmax, ymax],
                     [xmin, ymin], [xmax, ymin]])
h_field = np.array([h_0, h_0,
                    h_0, h_0])
h_init = griddata(h_points, h_field, Coords, method='linear')  # Linear interpolation

# Now that we have the mesh, we can interpolate H, phi and k.
H = H_function(mesh, H_points, H_field.flatten(), ME1)
k = k_function(mesh, k_points, k_field.flatten(), ME1)
phi = phi_function(mesh, phi_points, phi_field.flatten(), ME1)
depth = depth_function(mesh, depth_points, depth_field.flatten(), ME1)

print('Removing nan values...')
for i in tqdm(range(len(Coords))):
    if np.isnan(H.vector().get_local()[i]): H.vector().get_local()[i] = np.nanmean(Hf.vector().get_local())
    if np.isnan(p_init[i]) and not np.isnan(p_init[i-1]): p_init[i] = p_init[i-1]
    elif np.isnan(p_init[i]): p_init[i] = p_0
    if np.isnan(h_init[i]) : h_init[i] = h_0
print('...removed')

print('Interpolating initial conditions...')
u_init = InitialConditions(p_init, h_init, Coords, ME1)
u.interpolate(u_init)
u0.interpolate(u_init)
print('... interpolated')

# Display real injected mass. This function can be used to verify the amount of the fluid which is injected at a given time.
t_inj = 10*day # Time when we want to verify the injected mass (mass flow rate).
s_g_ = Function(ME1) ; s_g_.interpolate(s(Sources_g, t_inj, ME1, sigma))
print('Injected mass at t = ' + day_format(t_inj) + ' : ' + str(assemble(s_g_*dx)) + ' kg.s-1')

# Plot
plot_initial_conditions(figures_output, Sources_g, u, h_field, Outline_array)
plot_AOI(plt.gca(), AOI, 'black')
plot_extraction_data(figures_output, Sources_g, T_tot)
plot_phi_k_H_depth(figures_output, Sources_g, Outline_array, k, H, phi, depth)
plot_AOI(plt.gca(), AOI, 'black')
# Out:
# Removing nan values...
# 100%|██████████| 3002/3002 [00:00<00:00, 24726.20it/s]
# ...removed
# Interpolating initial conditions...
# ... interpolated
# Injected mass at t = 10.0 days : 0.0 kg.s-1

# %% [markdown]
# # Calculating the topography of the reservoir

# %%
gradi = grad(depth+H)
gradient = project(gradi,ME2) 
gradient_values = gradient.compute_vertex_values(mesh) #to get all the data  from gradient

# Calcul for the gradient in the X direction
gradient_X = []
for i in range(0,int(len(gradient_values)/2)):
    gradient_X.append(gradient_values[i])

# Calcul for the gradient in the Y direction
gradient_Y = []
for i in range(int(len(gradient_values)/2),len(gradient_values)):
    gradient_Y.append(gradient_values[i])

# Creation of a panda fram
panda = pd.DataFrame({'Coord X':mesh.coordinates()[:,0],'Coord Y':mesh.coordinates()[:,1],'Grad X':gradient_X[:],'Grad Y':gradient_Y[:] })

# Calcul of the norme of the gradient
Norme=[]
for i in range(len(panda['Grad Y'])):
    Norme_numpy = math.sqrt(panda['Grad X'][i]**2+panda['Grad Y'][i]**2)
    Norme.append(Norme_numpy)
panda['Norme Gradient']=Norme

# Transposition du gradient; norme(gradient)=angle
angle_Points = np.array(list(zip(panda['Coord X'], panda['Coord Y'])))

x_mesh = np.linspace(xmin, xmax, num=100)  # Vous pouvez ajuster le nombre de points de la grille si nécessaire
y_mesh = np.linspace(ymin, ymax, num=100)
X_mesh, Y_mesh = np.meshgrid(x_mesh, y_mesh)
angle_rad_panda = griddata((panda['Coord X'],panda['Coord Y']),panda['Norme Gradient'], (X_mesh,Y_mesh),method='linear')

# Plot de l'angle
plt.figure(figsize=(7, 6))
plt.scatter(X_mesh,Y_mesh,c=angle_rad_panda, s=10)
plt.colorbar()
plt.title('Value of the angle[rad]')
plt.xlabel('X[m]')
plt.ylabel('Y[m]')
angle_value=np.array(panda['Norme Gradient'])
ax = plt.gca()
plot_AOI(ax, AOI, 'red')
angle_points = np.array(list(zip(panda['Coord X'], panda['Coord Y'])))
angle_rad = angle_function(mesh, angle_points, angle_value.flatten(), ME1)

# %% [markdown]
# # Boundary conditions

# %%
use_boundary = False

if use_boundary:
    u_bound = InitialConditions(p_init, h_init, Coords, ME1)

    def boundary_L(x, on_boundary):
        tol = 1000
        if on_boundary:
            for vertice in Outline_array:
                if near(x[0], vertice[0], tol) and near(x[1], vertice[1], tol):
                    return True
        return False

    bc = DirichletBC(ME, u_bound, boundary_L)
    bcs = [bc]
else:
    bcs = []

# %% [markdown]
# # Define problem

# %%
# Step in time
t = 0.0 # Initialize initial time
Nt = 0 # Initialize number of iterations
List_t = [t] # Create list of step times

problem = define_problem_topography(dt, t,
                                    Sources_g,
                                    ME1,
                                    H, phi, sg, g,
                                    rho_g, rho_w, rho_g0, rho_w0, mug, muw,
                                    cr, cg, cw,
                                    u, p, h, p0, h0, du,
                                    sigma,
                                    v_p, v_h,
                                    k, krg, krw, bcs, depth, angle_rad)

solver = NewtonSolver()
solver.parameters["linear_solver"] = "gmres" # mumps
solver.parameters["convergence_criterion"] = "incremental" # "residual"
solver.parameters["relative_tolerance"] = 1e-8
solver.parameters["absolute_tolerance"] = 1e-7
solver.parameters["maximum_iterations"] = 20

# %% [markdown]
# # Main loop (data saved in the main loop)

# %%
# Prepare folder to save results
file_p = File (output_folder + "/p" + "/output_p.pvd")
file_h = File (output_folder + "/h" + "/output_h.pvd")
file_p << u.split()[0] ; file_h << u.split()[1]
file_H = File (output_folder + "/H.pvd") ; file_H << H

Mass_found0 = assemble(h*rho_g(p)*phi*dx)*sg # Initial CO2 mass found
List_err = [0] # Create list to save relative difference of CO2 mass (between injected and found)
time0 = time.time() # Save current time to calculate loop duration

while (t < T_tot):
    Nt += 1
    
    print(Fore.BLUE+'Iteration ' + str(Nt) + ' : t = '+day_format(t)+' ------> t = '+day_format(t+dt) + ' (dt = ' + day_format(dt) + ')' )
    print(Style.RESET_ALL)
    t += dt ; List_t.append(t)
    
    u0.vector()[:] = u.vector()[:] # Initialize new value
    (no_of_iterations,converged) = solver.solve(problem, u.vector()) # Solve problem
    Mass_found = assemble(h*rho_g(p)*phi*dx)*sg
    Expected_injected_mass = injected_mass(t, Sources_g)
    if no_of_iterations > 10 : dt /= 16
    elif no_of_iterations > 4 : dt /= 2
    elif dt<dt_max/2 : dt *= 2
    
    # Redefine the problem with new values
    problem = define_problem_topography(dt, t,
                                        Sources_g,
                                        ME1,
                                        H, phi, sg, g,
                                        rho_g, rho_w, rho_g0, rho_w0, mug, muw,
                                        cr, cg, cw,
                                        u, p, h, p0, h0, du,
                                        sigma,
                                        v_p, v_h,
                                        k, krg, krw, bcs, depth, angle_rad)
    
    file_p << u.split()[0]
    file_h << u.split()[1]
    
    print(Fore.GREEN + 'Expected injected mass at t = ' + day_format(t) + " : " + str(Expected_injected_mass*1e-9) + ' Mt')
    print(Fore.GREEN + 'Injected mass found at t = ' + day_format(t) + " : " + str((Mass_found-Mass_found0)*1e-9) + ' Mt (cumulative)')
    if Expected_injected_mass != 0:
        print(Fore.GREEN + 'Relative difference = ' + str(100*abs((Expected_injected_mass-Mass_found+Mass_found0)/Expected_injected_mass)) + ' %')
        List_err.append(abs((Expected_injected_mass-Mass_found+Mass_found0)/Expected_injected_mass))
    else:
        List_err.append(0)

timef = time.time()
# Out:
# Iteration 1 : t = 0 s ------> t = 1 min (dt = 1 min)
#
# Newton iteration 0: r (abs) = 2.940e-09 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 4 linear solver iterations.
# Expected injected mass at t = 1 min : 0.0 Mt
# Injected mass found at t = 1 min : 0.0 Mt (cumulative)
# Iteration 2 : t = 1 min ------> t = 3 min (dt = 2 min)
#
# Newton iteration 0: r (abs) = 3.795e-09 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 4 linear solver iterations.
# Expected injected mass at t = 3 min : 0.0 Mt
# Injected mass found at t = 3 min : 0.0 Mt (cumulative)
# Iteration 3 : t = 3 min ------> t = 7 min (dt = 4 min)
#
# Newton iteration 0: r (abs) = 4.742e-09 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 5 linear solver iterations.
# Expected injected mass at t = 7 min : 0.0 Mt
# Injected mass found at t = 7 min : 0.0 Mt (cumulative)
# Iteration 4 : t = 7 min ------> t = 15 min (dt = 8 min)
#
# Newton iteration 0: r (abs) = 5.849e-09 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 7 linear solver iterations.
# Expected injected mass at t = 15 min : 0.0 Mt
# Injected mass found at t = 15 min : 0.0 Mt (cumulative)
# Iteration 5 : t = 15 min ------> t = 31 min (dt = 16 min)
#
# Newton iteration 0: r (abs) = 7.263e-09 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 9 linear solver iterations.
# Expected injected mass at t = 31 min : 0.0 Mt
# Injected mass found at t = 31 min : 0.0 Mt (cumulative)
# Iteration 6 : t = 31 min ------> t = 1.0 h (dt = 32 min)
#
# Newton iteration 0: r (abs) = 9.276e-09 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 11 linear solver iterations.
# Expected injected mass at t = 1.0 h : 0.0 Mt
# Injected mass found at t = 1.0 h : 0.0 Mt (cumulative)
# Iteration 7 : t = 1.0 h ------> t = 2.1 h (dt = 1.0 h)
#
# Newton iteration 0: r (abs) = 1.237e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 14 linear solver iterations.
# Expected injected mass at t = 2.1 h : 0.0 Mt
# Injected mass found at t = 2.1 h : 0.0 Mt (cumulative)
# Iteration 8 : t = 2.1 h ------> t = 4.2 h (dt = 2.1 h)
#
# Newton iteration 0: r (abs) = 1.698e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 17 linear solver iterations.
# Expected injected mass at t = 4.2 h : 0.0 Mt
# Injected mass found at t = 4.2 h : 0.0 Mt (cumulative)
# Iteration 9 : t = 4.2 h ------> t = 8.5 h (dt = 4.2 h)
#
# Newton iteration 0: r (abs) = 2.304e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 20 linear solver iterations.
# Expected injected mass at t = 8.5 h : 0.0 Mt
# Injected mass found at t = 8.5 h : 0.0 Mt (cumulative)
# Iteration 10 : t = 8.5 h ------> t = 17.0 h (dt = 8.5 h)
#
# Newton iteration 0: r (abs) = 2.856e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 22 linear solver iterations.
# Expected injected mass at t = 17.0 h : 0.0 Mt
# Injected mass found at t = 17.0 h : 0.0 Mt (cumulative)
# Iteration 11 : t = 17.0 h ------> t = 1.4 days (dt = 17.0 h)
#
# Newton iteration 0: r (abs) = 3.054e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 26 linear solver iterations.
# Expected injected mass at t = 1.4 days : 0.0 Mt
# Injected mass found at t = 1.4 days : 0.0 Mt (cumulative)
# Iteration 12 : t = 1.4 days ------> t = 2.8 days (dt = 1.4 days)
#
# Newton iteration 0: r (abs) = 3.333e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 29 linear solver iterations.
# Expected injected mass at t = 2.8 days : 0.0 Mt
# Injected mass found at t = 2.8 days : 0.0 Mt (cumulative)
# Iteration 13 : t = 2.8 days ------> t = 5.6 days (dt = 2.8 days)
#
# Newton iteration 0: r (abs) = 3.907e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 33 linear solver iterations.
# Expected injected mass at t = 5.6 days : 0.0 Mt
# Injected mass found at t = 5.6 days : 0.0 Mt (cumulative)
# Iteration 14 : t = 5.6 days ------> t = 11.3 days (dt = 5.6 days)
#
# Newton iteration 0: r (abs) = 4.615e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 37 linear solver iterations.
# Expected injected mass at t = 11.3 days : 0.0 Mt
# Injected mass found at t = 11.3 days : 0.0 Mt (cumulative)
# Iteration 15 : t = 11.3 days ------> t = 22.7 days (dt = 11.3 days)
#
# Newton iteration 0: r (abs) = 5.330e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 39 linear solver iterations.
# Expected injected mass at t = 22.7 days : 0.0 Mt
# Injected mass found at t = 22.7 days : 0.0 Mt (cumulative)
# Iteration 16 : t = 22.7 days ------> t = 45.5 days (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 5.783e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 47 linear solver iterations.
# Expected injected mass at t = 45.5 days : 0.0 Mt
# Injected mass found at t = 45.5 days : 0.0 Mt (cumulative)
# Iteration 17 : t = 45.5 days ------> t = 91.0 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 6.531e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 51 linear solver iterations.
# Expected injected mass at t = 91.0 days : 0.0 Mt
# Injected mass found at t = 91.0 days : 0.0 Mt (cumulative)
# Iteration 18 : t = 91.0 days ------> t = 136.5 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 136.5 days : 0.0 Mt
# Injected mass found at t = 136.5 days : 0.0 Mt (cumulative)
# Iteration 19 : t = 136.5 days ------> t = 182.0 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 182.0 days : 0.0 Mt
# Injected mass found at t = 182.0 days : 0.0 Mt (cumulative)
# Iteration 20 : t = 182.0 days ------> t = 227.5 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 227.5 days : 0.0 Mt
# Injected mass found at t = 227.5 days : 0.0 Mt (cumulative)
# Iteration 21 : t = 227.5 days ------> t = 273.0 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 273.0 days : 0.0 Mt
# Injected mass found at t = 273.0 days : 0.0 Mt (cumulative)
# Iteration 22 : t = 273.0 days ------> t = 318.5 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 318.5 days : 0.0 Mt
# Injected mass found at t = 318.5 days : 0.0 Mt (cumulative)
# Iteration 23 : t = 318.5 days ------> t = 364.0 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 364.0 days : 0.0 Mt
# Injected mass found at t = 364.0 days : 0.0 Mt (cumulative)
# Iteration 24 : t = 364.0 days ------> t = 1.12 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 1.12 years : 0.0 Mt
# Injected mass found at t = 1.12 years : 0.0 Mt (cumulative)
# Iteration 25 : t = 1.12 years ------> t = 1.24 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 1.24 years : 0.0 Mt
# Injected mass found at t = 1.24 years : 0.0 Mt (cumulative)
# Iteration 26 : t = 1.24 years ------> t = 1.37 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 1.37 years : 0.0 Mt
# Injected mass found at t = 1.37 years : 0.0 Mt (cumulative)
# Iteration 27 : t = 1.37 years ------> t = 1.49 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 1.49 years : 0.0 Mt
# Injected mass found at t = 1.49 years : 0.0 Mt (cumulative)
# Iteration 28 : t = 1.49 years ------> t = 1.62 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 1.62 years : 0.0 Mt
# Injected mass found at t = 1.62 years : 0.0 Mt (cumulative)
# Iteration 29 : t = 1.62 years ------> t = 1.74 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 1.74 years : 0.0 Mt
# Injected mass found at t = 1.74 years : 0.0 Mt (cumulative)
# Iteration 30 : t = 1.74 years ------> t = 1.87 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 1.87 years : 0.0 Mt
# Injected mass found at t = 1.87 years : 0.0 Mt (cumulative)
# Iteration 31 : t = 1.87 years ------> t = 1.99 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 1.99 years : 0.0 Mt
# Injected mass found at t = 1.99 years : 0.0 Mt (cumulative)
# Iteration 32 : t = 1.99 years ------> t = 2.11 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 2.11 years : 0.0 Mt
# Injected mass found at t = 2.11 years : 0.0 Mt (cumulative)
# Iteration 33 : t = 2.11 years ------> t = 2.24 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 2.24 years : 0.0 Mt
# Injected mass found at t = 2.24 years : 0.0 Mt (cumulative)
# Iteration 34 : t = 2.24 years ------> t = 2.36 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 2.36 years : 0.0 Mt
# Injected mass found at t = 2.36 years : 0.0 Mt (cumulative)
# Iteration 35 : t = 2.36 years ------> t = 2.49 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 2.49 years : 0.0 Mt
# Injected mass found at t = 2.49 years : 0.0 Mt (cumulative)
# Iteration 36 : t = 2.49 years ------> t = 2.61 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 2.61 years : 0.0 Mt
# Injected mass found at t = 2.61 years : 0.0 Mt (cumulative)
# Iteration 37 : t = 2.61 years ------> t = 2.74 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 2.74 years : 0.0 Mt
# Injected mass found at t = 2.74 years : 0.0 Mt (cumulative)
# Iteration 38 : t = 2.74 years ------> t = 2.86 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 2.86 years : 0.0 Mt
# Injected mass found at t = 2.86 years : 0.0 Mt (cumulative)
# Iteration 39 : t = 2.86 years ------> t = 2.99 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 2.99 years : 0.0 Mt
# Injected mass found at t = 2.99 years : 0.0 Mt (cumulative)
# Iteration 40 : t = 2.99 years ------> t = 3.11 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)Expected injected mass at t = 3.11 years : 0.0 Mt
# Injected mass found at t = 3.11 years : 0.0 Mt (cumulative)
# Iteration 41 : t = 3.11 years ------> t = 3.24 years (dt = 45.5 days)
#
#
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 3.24 years : 0.0 Mt
# Injected mass found at t = 3.24 years : 0.0 Mt (cumulative)
# Iteration 42 : t = 3.24 years ------> t = 3.36 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 3.36 years : 0.0 Mt
# Injected mass found at t = 3.36 years : 0.0 Mt (cumulative)
# Iteration 43 : t = 3.36 years ------> t = 3.49 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 3.49 years : 0.0 Mt
# Injected mass found at t = 3.49 years : 0.0 Mt (cumulative)
# Iteration 44 : t = 3.49 years ------> t = 3.61 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 3.61 years : 0.0 Mt
# Injected mass found at t = 3.61 years : 0.0 Mt (cumulative)
# Iteration 45 : t = 3.61 years ------> t = 3.74 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 3.74 years : 0.0 Mt
# Injected mass found at t = 3.74 years : 0.0 Mt (cumulative)
# Iteration 46 : t = 3.74 years ------> t = 3.86 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 3.86 years : 0.0 Mt
# Injected mass found at t = 3.86 years : 0.0 Mt (cumulative)
# Iteration 47 : t = 3.86 years ------> t = 3.99 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 3.99 years : 0.0 Mt
# Injected mass found at t = 3.99 years : 0.0 Mt (cumulative)
# Iteration 48 : t = 3.99 years ------> t = 4.11 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 4.11 years : 0.0 Mt
# Injected mass found at t = 4.11 years : 0.0 Mt (cumulative)
# Iteration 49 : t = 4.11 years ------> t = 4.23 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 4.23 years : 0.0 Mt
# Injected mass found at t = 4.23 years : 0.0 Mt (cumulative)
# Iteration 50 : t = 4.23 years ------> t = 4.36 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 4.36 years : 0.0 Mt
# Injected mass found at t = 4.36 years : 0.0 Mt (cumulative)
# Iteration 51 : t = 4.36 years ------> t = 4.48 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 4.48 years : 0.0 Mt
# Injected mass found at t = 4.48 years : 0.0 Mt (cumulative)
# Iteration 52 : t = 4.48 years ------> t = 4.61 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 4.61 years : 0.0 Mt
# Injected mass found at t = 4.61 years : 0.0 Mt (cumulative)
# Iteration 53 : t = 4.61 years ------> t = 4.73 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 4.73 years : 0.0 Mt
# Injected mass found at t = 4.73 years : 0.0 Mt (cumulative)
# Iteration 54 : t = 4.73 years ------> t = 4.86 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 4.86 years : 0.0 Mt
# Injected mass found at t = 4.86 years : 0.0 Mt (cumulative)
# Iteration 55 : t = 4.86 years ------> t = 4.98 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 4.98 years : 0.0 Mt
# Injected mass found at t = 4.98 years : 0.0 Mt (cumulative)
# Iteration 56 : t = 4.98 years ------> t = 5.11 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.767e-08 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton solver finished in 1 iterations and 41 linear solver iterations.
# Expected injected mass at t = 5.11 years : 0.12118150684931508 Mt
# Injected mass found at t = 5.11 years : 0.0 Mt (cumulative)
# Relative difference = 100.0 %
# Iteration 57 : t = 5.11 years ------> t = 5.23 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.423e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.540e+05 (tol = 1.000e-07) r (rel) = 4.500e-02 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.180e+04 (tol = 1.000e-07) r (rel) = 9.292e-03 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.118e+03 (tol = 1.000e-07) r (rel) = 6.187e-04 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 1.669e+01 (tol = 1.000e-07) r (rel) = 4.877e-06 (tol = 1.000e-08)
# Newton iteration 5: r (abs) = 5.169e-03 (tol = 1.000e-07) r (rel) = 1.510e-09 (tol = 1.000e-08)
# Newton solver finished in 6 iterations and 240 linear solver iterations.
# Expected injected mass at t = 5.23 years : 0.2558445205479452 Mt
# Injected mass found at t = 5.23 years : 0.1345474214649959 Mt (cumulative)
# Relative difference = 47.41047368267489 %
# Iteration 58 : t = 5.23 years ------> t = 5.29 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 6.574e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.198e+03 (tol = 1.000e-07) r (rel) = 6.385e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.078e+00 (tol = 1.000e-07) r (rel) = 3.161e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 7.521e-04 (tol = 1.000e-07) r (rel) = 1.144e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 191 linear solver iterations.
# Expected injected mass at t = 5.29 years : 0.32317602739726026 Mt
# Injected mass found at t = 5.29 years : 0.2021200342565805 Mt (cumulative)
# Relative difference = 37.45822179807698 %
# Iteration 59 : t = 5.29 years ------> t = 5.42 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 7.522e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.499e+03 (tol = 1.000e-07) r (rel) = 9.969e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.656e+01 (tol = 1.000e-07) r (rel) = 4.861e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.851e-02 (tol = 1.000e-07) r (rel) = 3.790e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 1.780e-06 (tol = 1.000e-07) r (rel) = 2.366e-12 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 251 linear solver iterations.
# Expected injected mass at t = 5.42 years : 0.4578390410958904 Mt
# Injected mass found at t = 5.42 years : 0.33722405253342325 Mt (cumulative)
# Relative difference = 26.344408784746996 %
# Iteration 60 : t = 5.42 years ------> t = 5.48 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 3.043e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.874e+03 (tol = 1.000e-07) r (rel) = 6.158e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.433e-01 (tol = 1.000e-07) r (rel) = 1.786e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.613e-04 (tol = 1.000e-07) r (rel) = 8.587e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 197 linear solver iterations.
# Expected injected mass at t = 5.48 years : 0.5251705479452055 Mt
# Injected mass found at t = 5.48 years : 0.4049789430677848 Mt (cumulative)
# Relative difference = 22.88620436688332 %
# Iteration 61 : t = 5.48 years ------> t = 5.61 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.730e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.404e+03 (tol = 1.000e-07) r (rel) = 9.311e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.458e+01 (tol = 1.000e-07) r (rel) = 3.081e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 6.899e-03 (tol = 1.000e-07) r (rel) = 1.458e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 2.647e-07 (tol = 1.000e-07) r (rel) = 5.597e-13 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 222 linear solver iterations.
# Expected injected mass at t = 5.61 years : 0.6598335616438356 Mt
# Injected mass found at t = 5.61 years : 0.5402260738133751 Mt (cumulative)
# Relative difference = 18.126917874938616 %
# Iteration 62 : t = 5.61 years ------> t = 5.67 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 2.129e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.212e+03 (tol = 1.000e-07) r (rel) = 5.696e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.045e-01 (tol = 1.000e-07) r (rel) = 1.431e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 9.164e-05 (tol = 1.000e-07) r (rel) = 4.305e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 201 linear solver iterations.
# Expected injected mass at t = 5.67 years : 0.7271650684931508 Mt
# Injected mass found at t = 5.67 years : 0.6081001752695097 Mt (cumulative)
# Relative difference = 16.373846652228526 %
# Iteration 63 : t = 5.67 years ------> t = 5.79 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.703e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.077e+03 (tol = 1.000e-07) r (rel) = 8.309e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.954e+00 (tol = 1.000e-07) r (rel) = 2.148e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 4.448e-03 (tol = 1.000e-07) r (rel) = 1.201e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 1.640e-07 (tol = 1.000e-07) r (rel) = 4.430e-13 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 226 linear solver iterations.
# Expected injected mass at t = 5.79 years : 0.8618280821917809 Mt
# Injected mass found at t = 5.79 years : 0.7434700940106433 Mt (cumulative)
# Relative difference = 13.733364069563889 %
# Iteration 64 : t = 5.79 years ------> t = 5.86 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 1.744e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.966e+02 (tol = 1.000e-07) r (rel) = 5.140e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.179e-01 (tol = 1.000e-07) r (rel) = 1.249e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.877e-05 (tol = 1.000e-07) r (rel) = 3.369e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 209 linear solver iterations.
# Expected injected mass at t = 5.86 years : 0.9291595890410961 Mt
# Injected mass found at t = 5.86 years : 0.8114483516010009 Mt (cumulative)
# Relative difference = 12.668570483308955 %
# Iteration 65 : t = 5.86 years ------> t = 5.98 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.213e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.374e+03 (tol = 1.000e-07) r (rel) = 7.388e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 4.751e+00 (tol = 1.000e-07) r (rel) = 1.479e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 3.285e-03 (tol = 1.000e-07) r (rel) = 1.022e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 8.114e-08 (tol = 1.000e-07) r (rel) = 2.525e-13 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 221 linear solver iterations.
# Expected injected mass at t = 5.98 years : 1.0638226027397262 Mt
# Injected mass found at t = 5.98 years : 0.9468540573381805 Mt (cumulative)
# Relative difference = 10.99511752244308 %
# Iteration 66 : t = 5.98 years ------> t = 6.04 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 1.550e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.159e+02 (tol = 1.000e-07) r (rel) = 4.619e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.790e-01 (tol = 1.000e-07) r (rel) = 1.155e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.886e-05 (tol = 1.000e-07) r (rel) = 1.862e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 210 linear solver iterations.
# Expected injected mass at t = 6.04 years : 1.1311541095890412 Mt
# Injected mass found at t = 6.04 years : 1.014873571014412 Mt (cumulative)
# Relative difference = 10.279814004908227 %
# Iteration 67 : t = 6.04 years ------> t = 6.17 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.947e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.952e+03 (tol = 1.000e-07) r (rel) = 6.623e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.395e+00 (tol = 1.000e-07) r (rel) = 1.152e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 4.508e-03 (tol = 1.000e-07) r (rel) = 1.530e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 8.764e-08 (tol = 1.000e-07) r (rel) = 2.974e-13 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 242 linear solver iterations.
# Expected injected mass at t = 6.17 years : 1.2658171232876712 Mt
# Injected mass found at t = 6.17 years : 1.1503483884917098 Mt (cumulative)
# Relative difference = 9.12207084828002 %
# Iteration 68 : t = 6.17 years ------> t = 6.23 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 1.440e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.971e+02 (tol = 1.000e-07) r (rel) = 4.145e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.296e-01 (tol = 1.000e-07) r (rel) = 8.998e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.243e-05 (tol = 1.000e-07) r (rel) = 8.628e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 212 linear solver iterations.
# Expected injected mass at t = 6.23 years : 1.3331486301369864 Mt
# Injected mass found at t = 6.23 years : 1.2184627254231077 Mt (cumulative)
# Relative difference = 8.60263455411526 %
# Iteration 69 : t = 6.23 years ------> t = 6.35 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.789e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.638e+03 (tol = 1.000e-07) r (rel) = 5.872e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.666e+00 (tol = 1.000e-07) r (rel) = 9.559e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.938e-03 (tol = 1.000e-07) r (rel) = 1.053e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 6.641e-08 (tol = 1.000e-07) r (rel) = 2.381e-13 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 242 linear solver iterations.
# Expected injected mass at t = 6.35 years : 1.4678116438356166 Mt
# Injected mass found at t = 6.35 years : 1.3539813637522224 Mt (cumulative)
# Relative difference = 7.755101314357907 %
# Iteration 70 : t = 6.35 years ------> t = 6.42 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 1.374e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.104e+02 (tol = 1.000e-07) r (rel) = 3.716e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.890e-02 (tol = 1.000e-07) r (rel) = 6.472e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.336e-05 (tol = 1.000e-07) r (rel) = 9.727e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 216 linear solver iterations.
# Expected injected mass at t = 6.42 years : 1.5351431506849316 Mt
# Injected mass found at t = 6.42 years : 1.4222044994662768 Mt (cumulative)
# Relative difference = 7.356880768302636 %
# Iteration 71 : t = 6.42 years ------> t = 6.54 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.688e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.464e+03 (tol = 1.000e-07) r (rel) = 5.447e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.892e+00 (tol = 1.000e-07) r (rel) = 7.039e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.457e-03 (tol = 1.000e-07) r (rel) = 5.419e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 210 linear solver iterations.
# Expected injected mass at t = 6.54 years : 1.6698061643835618 Mt
# Injected mass found at t = 6.54 years : 1.5578244370905738 Mt (cumulative)
# Relative difference = 6.706271044000359 %
# Iteration 72 : t = 6.54 years ------> t = 6.67 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.639e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.336e+03 (tol = 1.000e-07) r (rel) = 5.063e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.440e+00 (tol = 1.000e-07) r (rel) = 5.457e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.097e-03 (tol = 1.000e-07) r (rel) = 4.158e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 211 linear solver iterations.
# Expected injected mass at t = 6.67 years : 1.804469178082192 Mt
# Injected mass found at t = 6.67 years : 1.6938503572270716 Mt (cumulative)
# Relative difference = 6.1302693445109 %
# Iteration 73 : t = 6.67 years ------> t = 6.79 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.599e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.213e+03 (tol = 1.000e-07) r (rel) = 4.669e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.166e+00 (tol = 1.000e-07) r (rel) = 4.488e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 8.401e-04 (tol = 1.000e-07) r (rel) = 3.233e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 213 linear solver iterations.
# Expected injected mass at t = 6.79 years : 1.939132191780822 Mt
# Injected mass found at t = 6.79 years : 1.8301034925903654 Mt (cumulative)
# Relative difference = 5.6225511418243626 %
# Iteration 74 : t = 6.79 years ------> t = 6.92 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.564e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.126e+03 (tol = 1.000e-07) r (rel) = 4.393e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.033e+00 (tol = 1.000e-07) r (rel) = 4.027e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 6.380e-04 (tol = 1.000e-07) r (rel) = 2.488e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 200 linear solver iterations.
# Expected injected mass at t = 6.92 years : 2.073795205479452 Mt
# Injected mass found at t = 6.92 years : 1.966510915396554 Mt (cumulative)
# Relative difference = 5.1733309923481325 %
# Iteration 75 : t = 6.92 years ------> t = 7.04 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.535e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.040e+03 (tol = 1.000e-07) r (rel) = 4.103e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.853e-01 (tol = 1.000e-07) r (rel) = 3.098e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 4.821e-04 (tol = 1.000e-07) r (rel) = 1.902e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 230 linear solver iterations.
# Expected injected mass at t = 7.04 years : 2.208458219178082 Mt
# Injected mass found at t = 7.04 years : 2.1031598574274843 Mt (cumulative)
# Relative difference = 4.767958063964933 %
# Iteration 76 : t = 7.04 years ------> t = 7.16 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.509e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 9.648e+02 (tol = 1.000e-07) r (rel) = 3.845e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.021e-01 (tol = 1.000e-07) r (rel) = 2.001e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 3.693e-04 (tol = 1.000e-07) r (rel) = 1.472e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 234 linear solver iterations.
# Expected injected mass at t = 7.16 years : 2.3431212328767126 Mt
# Injected mass found at t = 7.16 years : 2.240201643638841 Mt (cumulative)
# Relative difference = 4.3924141778833405 %
# Iteration 77 : t = 7.16 years ------> t = 7.29 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.486e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 9.029e+02 (tol = 1.000e-07) r (rel) = 3.632e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 4.148e-01 (tol = 1.000e-07) r (rel) = 1.668e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.335e-04 (tol = 1.000e-07) r (rel) = 9.390e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 239 linear solver iterations.
# Expected injected mass at t = 7.29 years : 2.477784246575342 Mt
# Injected mass found at t = 7.29 years : 2.377553272093826 Mt (cumulative)
# Relative difference = 4.045185718653677 %
# Iteration 78 : t = 7.29 years ------> t = 7.41 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.466e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.497e+02 (tol = 1.000e-07) r (rel) = 3.446e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.112e-01 (tol = 1.000e-07) r (rel) = 1.262e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.263e-04 (tol = 1.000e-07) r (rel) = 9.179e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 234 linear solver iterations.
# Expected injected mass at t = 7.41 years : 2.6124472602739726 Mt
# Injected mass found at t = 7.41 years : 2.515176321244729 Mt (cumulative)
# Relative difference = 3.723364697476915 %
# Iteration 79 : t = 7.41 years ------> t = 7.54 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.448e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.094e+02 (tol = 1.000e-07) r (rel) = 3.307e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.538e-01 (tol = 1.000e-07) r (rel) = 1.037e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.406e-04 (tol = 1.000e-07) r (rel) = 5.745e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 222 linear solver iterations.
# Expected injected mass at t = 7.54 years : 2.747110273972603 Mt
# Injected mass found at t = 7.54 years : 2.653130121169568 Mt (cumulative)
# Relative difference = 3.4210549788789457 %
# Iteration 80 : t = 7.54 years ------> t = 7.66 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.431e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.733e+02 (tol = 1.000e-07) r (rel) = 3.181e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.384e-01 (tol = 1.000e-07) r (rel) = 9.805e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 9.370e-05 (tol = 1.000e-07) r (rel) = 3.854e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 233 linear solver iterations.
# Expected injected mass at t = 7.66 years : 2.8817732876712334 Mt
# Injected mass found at t = 7.66 years : 2.7915191784776456 Mt (cumulative)
# Relative difference = 3.1318948502892923 %
# Iteration 81 : t = 7.66 years ------> t = 7.79 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.416e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.439e+02 (tol = 1.000e-07) r (rel) = 3.078e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.210e-01 (tol = 1.000e-07) r (rel) = 9.145e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 7.108e-05 (tol = 1.000e-07) r (rel) = 2.941e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 234 linear solver iterations.
# Expected injected mass at t = 7.79 years : 3.0164363013698634 Mt
# Injected mass found at t = 7.79 years : 2.9302852062154554 Mt (cumulative)
# Relative difference = 2.8560555087897574 %
# Iteration 82 : t = 7.79 years ------> t = 7.91 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.403e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.273e+02 (tol = 1.000e-07) r (rel) = 3.026e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.796e-01 (tol = 1.000e-07) r (rel) = 7.473e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 4.576e-05 (tol = 1.000e-07) r (rel) = 1.904e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 225 linear solver iterations.
# Expected injected mass at t = 7.91 years : 3.151099315068493 Mt
# Injected mass found at t = 7.91 years : 3.0693215347141063 Mt (cumulative)
# Relative difference = 2.5952143102353875 %
# Iteration 83 : t = 7.91 years ------> t = 8.04 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.391e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.089e+02 (tol = 1.000e-07) r (rel) = 2.965e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.617e-01 (tol = 1.000e-07) r (rel) = 6.762e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 3.898e-05 (tol = 1.000e-07) r (rel) = 1.630e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 245 linear solver iterations.
# Expected injected mass at t = 8.04 years : 3.2857623287671234 Mt
# Injected mass found at t = 8.04 years : 3.2085601709622384 Mt (cumulative)
# Relative difference = 2.349596534386361 %
# Iteration 84 : t = 8.04 years ------> t = 8.16 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.380e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.995e+02 (tol = 1.000e-07) r (rel) = 2.939e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.172e-01 (tol = 1.000e-07) r (rel) = 4.925e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.436e-05 (tol = 1.000e-07) r (rel) = 6.036e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 205 linear solver iterations.
# Expected injected mass at t = 8.16 years : 3.420425342465754 Mt
# Injected mass found at t = 8.16 years : 3.34794993043953 Mt (cumulative)
# Relative difference = 2.1189005684882685 %
# Iteration 85 : t = 8.16 years ------> t = 8.29 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.369e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.814e+02 (tol = 1.000e-07) r (rel) = 2.876e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.490e-02 (tol = 1.000e-07) r (rel) = 4.005e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.439e-05 (tol = 1.000e-07) r (rel) = 6.072e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 222 linear solver iterations.
# Expected injected mass at t = 8.29 years : 3.5550883561643842 Mt
# Injected mass found at t = 8.29 years : 3.4874404415661355 Mt (cumulative)
# Relative difference = 1.9028476319287435 %
# Iteration 86 : t = 8.29 years ------> t = 8.41 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.360e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.782e+02 (tol = 1.000e-07) r (rel) = 2.874e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.139e-02 (tol = 1.000e-07) r (rel) = 3.449e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.548e-05 (tol = 1.000e-07) r (rel) = 6.559e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 242 linear solver iterations.
# Expected injected mass at t = 8.41 years : 3.6897513698630147 Mt
# Injected mass found at t = 8.41 years : 3.6270469712268687 Mt (cumulative)
# Relative difference = 1.699420702118299 %
# Iteration 87 : t = 8.41 years ------> t = 8.54 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.351e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.630e+02 (tol = 1.000e-07) r (rel) = 2.820e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.018e-02 (tol = 1.000e-07) r (rel) = 2.985e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.300e-05 (tol = 1.000e-07) r (rel) = 5.527e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 250 linear solver iterations.
# Expected injected mass at t = 8.54 years : 3.8244143835616438 Mt
# Injected mass found at t = 8.54 years : 3.7668845247721356 Mt (cumulative)
# Relative difference = 1.5042789044196432 %
# Iteration 88 : t = 8.54 years ------> t = 8.66 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.343e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.669e+02 (tol = 1.000e-07) r (rel) = 2.846e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.739e-02 (tol = 1.000e-07) r (rel) = 2.449e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.843e-06 (tol = 1.000e-07) r (rel) = 2.493e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 233 linear solver iterations.
# Expected injected mass at t = 8.66 years : 3.959077397260274 Mt
# Injected mass found at t = 8.66 years : 3.9069051975703464 Mt (cumulative)
# Relative difference = 1.317786808765884 %
# Iteration 89 : t = 8.66 years ------> t = 8.79 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.336e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.535e+02 (tol = 1.000e-07) r (rel) = 2.798e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.438e-02 (tol = 1.000e-07) r (rel) = 2.328e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 7.192e-06 (tol = 1.000e-07) r (rel) = 3.079e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 233 linear solver iterations.
# Expected injected mass at t = 8.79 years : 4.093740410958905 Mt
# Injected mass found at t = 8.79 years : 4.0471860022022845 Mt (cumulative)
# Relative difference = 1.1372095952150434 %
# Iteration 90 : t = 8.79 years ------> t = 8.91 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.329e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.652e+02 (tol = 1.000e-07) r (rel) = 2.856e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.946e-02 (tol = 1.000e-07) r (rel) = 2.553e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.874e-06 (tol = 1.000e-07) r (rel) = 1.234e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 225 linear solver iterations.
# Expected injected mass at t = 8.91 years : 4.228403424657535 Mt
# Injected mass found at t = 8.91 years : 4.1877260435138055 Mt (cumulative)
# Relative difference = 0.9620033156373612 %
# Iteration 91 : t = 8.91 years ------> t = 9.03 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.322e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.535e+02 (tol = 1.000e-07) r (rel) = 2.814e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.535e-02 (tol = 1.000e-07) r (rel) = 2.383e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.094e-06 (tol = 1.000e-07) r (rel) = 9.018e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 234 linear solver iterations.
# Expected injected mass at t = 9.03 years : 4.363066438356165 Mt
# Injected mass found at t = 9.03 years : 4.32856810818514 Mt (cumulative)
# Relative difference = 0.7906900034284595 %
# Iteration 92 : t = 9.03 years ------> t = 9.16 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.316e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.422e+02 (tol = 1.000e-07) r (rel) = 2.773e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.509e-02 (tol = 1.000e-07) r (rel) = 2.379e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.174e-06 (tol = 1.000e-07) r (rel) = 5.068e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 235 linear solver iterations.
# Expected injected mass at t = 9.16 years : 4.497729452054795 Mt
# Injected mass found at t = 9.16 years : 4.469664027442193 Mt (cumulative)
# Relative difference = 0.6239909472496072 %
# Iteration 93 : t = 9.16 years ------> t = 9.28 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.310e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.314e+02 (tol = 1.000e-07) r (rel) = 2.733e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.313e-02 (tol = 1.000e-07) r (rel) = 2.300e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.601e-06 (tol = 1.000e-07) r (rel) = 6.930e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 219 linear solver iterations.
# Expected injected mass at t = 9.28 years : 4.632392465753425 Mt
# Injected mass found at t = 9.28 years : 4.610972734648926 Mt (cumulative)
# Relative difference = 0.46239025002418704 %
# Iteration 94 : t = 9.28 years ------> t = 9.41 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.305e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.694e+02 (tol = 1.000e-07) r (rel) = 2.904e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.354e-02 (tol = 1.000e-07) r (rel) = 3.190e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.490e-06 (tol = 1.000e-07) r (rel) = 1.080e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 220 linear solver iterations.
# Expected injected mass at t = 9.41 years : 4.767055479452055 Mt
# Injected mass found at t = 9.41 years : 4.752515710009474 Mt (cumulative)
# Relative difference = 0.30500524915754573 %
# Iteration 95 : t = 9.41 years ------> t = 9.53 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.300e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.598e+02 (tol = 1.000e-07) r (rel) = 2.869e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.006e-02 (tol = 1.000e-07) r (rel) = 3.046e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.370e-06 (tol = 1.000e-07) r (rel) = 5.955e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 222 linear solver iterations.
# Expected injected mass at t = 9.53 years : 4.9017184931506845 Mt
# Injected mass found at t = 9.53 years : 4.894247112197107 Mt (cumulative)
# Relative difference = 0.15242370536002783 %
# Iteration 96 : t = 9.53 years ------> t = 9.66 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.295e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# ...
# Newton iteration 1: r (abs) = 7.661e+00 (tol = 1.000e-07) r (rel) = 2.761e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.327e-05 (tol = 1.000e-07) r (rel) = 3.361e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.871e-08 (tol = 1.000e-07) r (rel) = 2.116e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 200 linear solver iterations.
# Expected injected mass at t = 52.3 years : 27.0 Mt
# Injected mass found at t = 52.3 years : 30.1464320972777 Mt (cumulative)
# Relative difference = 11.653452212139625 %
# Iteration 439 : t = 52.3 years ------> t = 52.43 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.759e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.622e+00 (tol = 1.000e-07) r (rel) = 2.762e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.215e-05 (tol = 1.000e-07) r (rel) = 3.339e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.930e-08 (tol = 1.000e-07) r (rel) = 2.149e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 195 linear solver iterations.
# Expected injected mass at t = 52.43 years : 27.0 Mt
# Injected mass found at t = 52.43 years : 30.152027873798268 Mt (cumulative)
# Relative difference = 11.674177310363953 %
# Iteration 440 : t = 52.43 years ------> t = 52.55 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.744e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.583e+00 (tol = 1.000e-07) r (rel) = 2.763e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.093e-05 (tol = 1.000e-07) r (rel) = 3.313e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.910e-08 (tol = 1.000e-07) r (rel) = 2.153e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 198 linear solver iterations.
# Expected injected mass at t = 52.55 years : 27.0 Mt
# Injected mass found at t = 52.55 years : 30.157593586925127 Mt (cumulative)
# Relative difference = 11.694791062685649 %
# Iteration 441 : t = 52.55 years ------> t = 52.68 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.729e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.545e+00 (tol = 1.000e-07) r (rel) = 2.764e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.962e-05 (tol = 1.000e-07) r (rel) = 3.284e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.915e-08 (tol = 1.000e-07) r (rel) = 2.167e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 202 linear solver iterations.
# Expected injected mass at t = 52.68 years : 27.0 Mt
# Injected mass found at t = 52.68 years : 30.163129369047635 Mt (cumulative)
# Relative difference = 11.715293959435682 %
# Iteration 442 : t = 52.68 years ------> t = 52.8 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.714e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.507e+00 (tol = 1.000e-07) r (rel) = 2.766e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.823e-05 (tol = 1.000e-07) r (rel) = 3.251e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.967e-08 (tol = 1.000e-07) r (rel) = 2.199e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 202 linear solver iterations.
# Expected injected mass at t = 52.8 years : 27.0 Mt
# Injected mass found at t = 52.8 years : 30.16863532316698 Mt (cumulative)
# Relative difference = 11.735686382099928 %
# Iteration 443 : t = 52.8 years ------> t = 52.93 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.699e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.469e+00 (tol = 1.000e-07) r (rel) = 2.767e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.675e-05 (tol = 1.000e-07) r (rel) = 3.214e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.923e-08 (tol = 1.000e-07) r (rel) = 2.194e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 199 linear solver iterations.
# Expected injected mass at t = 52.93 years : 27.0 Mt
# Injected mass found at t = 52.93 years : 30.174111512047855 Mt (cumulative)
# Relative difference = 11.755968563140192 %
# Iteration 444 : t = 52.93 years ------> t = 53.05 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.685e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.431e+00 (tol = 1.000e-07) r (rel) = 2.768e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.516e-05 (tol = 1.000e-07) r (rel) = 3.172e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.913e-08 (tol = 1.000e-07) r (rel) = 2.202e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 204 linear solver iterations.
# Expected injected mass at t = 53.05 years : 27.0 Mt
# Injected mass found at t = 53.05 years : 30.17955792754465 Mt (cumulative)
# Relative difference = 11.776140472387581 %
# Iteration 445 : t = 53.05 years ------> t = 53.17 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.670e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.394e+00 (tol = 1.000e-07) r (rel) = 2.769e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.345e-05 (tol = 1.000e-07) r (rel) = 3.125e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.912e-08 (tol = 1.000e-07) r (rel) = 2.214e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 204 linear solver iterations.
# Expected injected mass at t = 53.17 years : 27.0 Mt
# Injected mass found at t = 53.17 years : 30.18497383273597 Mt (cumulative)
# Relative difference = 11.796199380503591 %
# Iteration 446 : t = 53.17 years ------> t = 53.3 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.656e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.358e+00 (tol = 1.000e-07) r (rel) = 2.770e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.161e-05 (tol = 1.000e-07) r (rel) = 3.073e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.871e-08 (tol = 1.000e-07) r (rel) = 2.210e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 205 linear solver iterations.
# Expected injected mass at t = 53.3 years : 27.0 Mt
# Injected mass found at t = 53.3 years : 30.190358618074008 Mt (cumulative)
# Relative difference = 11.816143029903722 %
# Iteration 447 : t = 53.3 years ------> t = 53.42 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.642e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.322e+00 (tol = 1.000e-07) r (rel) = 2.772e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.964e-05 (tol = 1.000e-07) r (rel) = 3.015e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.922e-08 (tol = 1.000e-07) r (rel) = 2.242e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 198 linear solver iterations.
# Expected injected mass at t = 53.42 years : 27.0 Mt
# Injected mass found at t = 53.42 years : 30.195711815515697 Mt (cumulative)
# Relative difference = 11.835969687095162 %
# Iteration 448 : t = 53.42 years ------> t = 53.55 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.627e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.286e+00 (tol = 1.000e-07) r (rel) = 2.773e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.753e-05 (tol = 1.000e-07) r (rel) = 2.951e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.992e-08 (tol = 1.000e-07) r (rel) = 2.280e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 202 linear solver iterations.
# Expected injected mass at t = 53.55 years : 27.0 Mt
# Injected mass found at t = 53.55 years : 30.201033859828126 Mt (cumulative)
# Relative difference = 11.855680962326389 %
# Iteration 449 : t = 53.55 years ------> t = 53.67 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.613e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.250e+00 (tol = 1.000e-07) r (rel) = 2.774e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.534e-05 (tol = 1.000e-07) r (rel) = 2.883e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.908e-08 (tol = 1.000e-07) r (rel) = 2.261e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 202 linear solver iterations.
# Expected injected mass at t = 53.67 years : 27.0 Mt
# Injected mass found at t = 53.67 years : 30.20632581201617 Mt (cumulative)
# Relative difference = 11.875280785245076 %
# Iteration 450 : t = 53.67 years ------> t = 53.8 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.600e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.213e+00 (tol = 1.000e-07) r (rel) = 2.775e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.302e-05 (tol = 1.000e-07) r (rel) = 2.809e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.893e-08 (tol = 1.000e-07) r (rel) = 2.267e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 201 linear solver iterations.
# Expected injected mass at t = 53.8 years : 27.0 Mt
# Injected mass found at t = 53.8 years : 30.211588202146665 Mt (cumulative)
# Relative difference = 11.894771119061717 %
# Iteration 451 : t = 53.8 years ------> t = 53.92 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.586e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.177e+00 (tol = 1.000e-07) r (rel) = 2.776e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.058e-05 (tol = 1.000e-07) r (rel) = 2.730e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.877e-08 (tol = 1.000e-07) r (rel) = 2.273e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 198 linear solver iterations.
# Expected injected mass at t = 53.92 years : 27.0 Mt
# Injected mass found at t = 53.92 years : 30.216820972038615 Mt (cumulative)
# Relative difference = 11.914151748291157 %
# Iteration 452 : t = 53.92 years ------> t = 54.05 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.572e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.142e+00 (tol = 1.000e-07) r (rel) = 2.777e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.917e-05 (tol = 1.000e-07) r (rel) = 3.078e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.913e-08 (tol = 1.000e-07) r (rel) = 2.299e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 209 linear solver iterations.
# Expected injected mass at t = 54.05 years : 27.0 Mt
# Injected mass found at t = 54.05 years : 30.22202398958481 Mt (cumulative)
# Relative difference = 11.933422183647439 %
# Iteration 453 : t = 54.05 years ------> t = 54.17 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.559e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.106e+00 (tol = 1.000e-07) r (rel) = 2.777e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.990e-05 (tol = 1.000e-07) r (rel) = 3.123e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.917e-08 (tol = 1.000e-07) r (rel) = 2.313e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 207 linear solver iterations.
# Expected injected mass at t = 54.17 years : 27.0 Mt
# Injected mass found at t = 54.17 years : 30.227198078060823 Mt (cumulative)
# Relative difference = 11.952585474299338 %
# Iteration 454 : t = 54.17 years ------> t = 54.3 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.545e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.071e+00 (tol = 1.000e-07) r (rel) = 2.778e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.669e-05 (tol = 1.000e-07) r (rel) = 3.013e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.848e-08 (tol = 1.000e-07) r (rel) = 2.297e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 203 linear solver iterations.
# Expected injected mass at t = 54.3 years : 27.0 Mt
# Injected mass found at t = 54.3 years : 30.232342698181345 Mt (cumulative)
# Relative difference = 11.971639622893864 %
# Iteration 455 : t = 54.3 years ------> t = 54.42 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.532e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.036e+00 (tol = 1.000e-07) r (rel) = 2.779e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.365e-05 (tol = 1.000e-07) r (rel) = 2.909e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.893e-08 (tol = 1.000e-07) r (rel) = 2.328e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 208 linear solver iterations.
# Expected injected mass at t = 54.42 years : 27.0 Mt
# Injected mass found at t = 54.42 years : 30.237457484875613 Mt (cumulative)
# Relative difference = 11.990583277317075 %
# Iteration 456 : t = 54.42 years ------> t = 54.55 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.519e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.002e+00 (tol = 1.000e-07) r (rel) = 2.780e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.390e-05 (tol = 1.000e-07) r (rel) = 2.934e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.870e-08 (tol = 1.000e-07) r (rel) = 2.331e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 204 linear solver iterations.
# Expected injected mass at t = 54.55 years : 27.0 Mt
# Injected mass found at t = 54.55 years : 30.242542627870943 Mt (cumulative)
# Relative difference = 12.009417140262745 %
# Iteration 457 : t = 54.55 years ------> t = 54.67 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.506e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.968e+00 (tol = 1.000e-07) r (rel) = 2.781e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.117e-05 (tol = 1.000e-07) r (rel) = 2.840e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.946e-08 (tol = 1.000e-07) r (rel) = 2.373e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 203 linear solver iterations.
# Expected injected mass at t = 54.67 years : 27.0 Mt
# Injected mass found at t = 54.67 years : 30.24759838448463 Mt (cumulative)
# Relative difference = 12.028142164757877 %
# Iteration 458 : t = 54.67 years ------> t = 54.8 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.493e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.934e+00 (tol = 1.000e-07) r (rel) = 2.782e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.880e-05 (tol = 1.000e-07) r (rel) = 2.760e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.864e-08 (tol = 1.000e-07) r (rel) = 2.352e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 193 linear solver iterations.
# Expected injected mass at t = 54.8 years : 27.0 Mt
# Injected mass found at t = 54.8 years : 30.25262547807744 Mt (cumulative)
# Relative difference = 12.046761029916437 %
# Iteration 459 : t = 54.8 years ------> t = 54.92 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.480e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.901e+00 (tol = 1.000e-07) r (rel) = 2.783e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.671e-05 (tol = 1.000e-07) r (rel) = 2.690e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.954e-08 (tol = 1.000e-07) r (rel) = 2.401e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 206 linear solver iterations.
# Expected injected mass at t = 54.92 years : 27.0 Mt
# Injected mass found at t = 54.92 years : 30.25762448905423 Mt (cumulative)
# Relative difference = 12.065275885386036 %
# Iteration 460 : t = 54.92 years ------> t = 55.04 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.467e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.867e+00 (tol = 1.000e-07) r (rel) = 2.783e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.492e-05 (tol = 1.000e-07) r (rel) = 2.631e-08 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.932e-08 (tol = 1.000e-07) r (rel) = 2.404e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 203 linear solver iterations.
# Expected injected mass at t = 55.04 years : 27.0 Mt
# Injected mass found at t = 55.04 years : 30.26259572928497 Mt (cumulative)
# Relative difference = 12.083687886240627 %

# %% [markdown]
# # Loop data

# %%
print(Fore.BLUE + 'Number of iteration = ' + str(Nt))
print(Fore.GREEN + 'loop time = ' + day_format(timef - time0))
print(Style.RESET_ALL)

Mass_found = assemble(h*rho_g(p)*phi*dx)*sg # we consider the density as constant
Expected_injected_mass = injected_mass(t, Sources_g)

p_min, p_max, h_min, h_max = min_max_pressure_h_total(output_folder, Nt, H, g, sg, 50, rho_g, rho_w, List_t)

###########################################################################################################################
# Plot loop data
print('Minimum and maximum pressure in the reservoir during operation : ' + str(p_min) + ' / ' + str(p_max) + ' bar')
print('Minimum and maximum value of h during operation : ' + str(h_min) + ' / ' + str(h_max) + ' m')

#Plot relative error (for mass) curve
plt.figure(figsize=(14, 5))
plt.xlabel('Time (year)') ; plt.ylabel('Error (%)')
plt.plot(np.array(List_t)/(24*3600*365), 100*np.array(List_err), color='black')
plt.title('Relative error between injected mass and mass found at each step')
plt.savefig(os.path.join(figures_output, 'QUEST_Model_accuracy.png'), dpi=300, bbox_inches='tight')
# Out:
# Number of iteration = 460
# loop time = 2 min
#   0%|          | 0/460 [00:00<?, ?it/s]
# 100%|██████████| 460/460 [00:09<00:00, 50.08it/s]
# Minimum and maximum pressure in the reservoir during operation : 204.64999999999998 / 215.28058632722394 bar
# Minimum and maximum value of h during operation : -0.05648595056737498 / 15.30577810086981 m

# %% [markdown]
# # Save and plot results
# ### Top views

# %%
Nx = 1e3 ; Ny = 1e3 ; Nz = 1e3

plot_p(output_folder, figures_output, Nt, AOI, p_min, p_max, List_t, ME1, 320e3, 410e3, 5950e3, 6052e3)
plot_h(output_folder, figures_output, 258, AOI, h_min, h_max, List_t, ME1, 320e3, 410e3, 5950e3, 6052e3)
plot_h(output_folder, figures_output, Nt, AOI, h_min, h_max, List_t, ME1, 320e3, 410e3, 5950e3, 6052e3)
# Out:
# Maximum pressure at the interface at t = 55.04 years : 213.00113983698174 bar
# After interpolation : 213.00113983677775 bar
# Maximum pressure at the interface at t = 29.86 years : 15.29421472468491 bar
# After interpolation : 15.294214725426286 bar
# Maximum pressure at the interface at t = 55.04 years : 4.963978449668385 bar
# After interpolation : 4.963978448792527 bar

# %%
def export_p(folder, iteration, Nx, Ny, Nz, List_t, AOI, Outline, phi0, k0):
    points_init, pressure_int, h = extract_points_p_h(folder, iteration)
    points = [] ; P = []

    for i in tqdm(range(len(points_init))):
        points.append([points_init[i][0], points_init[i][1]])

    X = np.linspace(Outline[0][0], Outline[1][0], int(Nx)) ; Y = np.linspace(Outline[0][1], Outline[2][1], int(Ny))
    grid_x, grid_y = np.meshgrid(X, Y)

    grid_z = np.array(griddata(points, pressure_int, (grid_x, grid_y), method='linear')) #interpolate the data
    pkl.dump(X, open('Figures data/QUEST/p_no_topo_Porosity_permeability_variation_data_X'+str(phi0)+'-'+str(k0)+'.p', 'wb'))
    pkl.dump(Y, open('Figures data/QUEST/p_no_topo_Porosity_permeability_variation_data_Y'+str(phi0)+'-'+str(k0)+'.p', 'wb'))
    pkl.dump(grid_z, open('Figures data/QUEST/p_no_topo_Porosity_permeability_variation_data_P'+str(phi0)+'-'+str(k0)+'.p', 'wb'))

def export_h(folder, iteration, Nx, Ny, Nz, List_t, AOI, Outline, phi0, k0):
    points_init, pressure_int, h = extract_points_p_h(folder, iteration)
    points = [] ; h_data = []

    for i in tqdm(range(len(points_init))):
        points.append([points_init[i][0], points_init[i][1]])
        h_data.append(h[i])
    X = np.linspace(Outline[0][0], Outline[1][0], int(Nx)) ; Y = np.linspace(Outline[0][1], Outline[2][1], int(Ny))
    grid_x, grid_y = np.meshgrid(X, Y)

    grid_z = np.array(griddata(points, h_data, (grid_x, grid_y), method='linear')) #interpolate the data
    pkl.dump(X, open('Figures data/QUEST/h_no_topo_Porosity_permeability_variation_data_X'+str(phi0)+'-'+str(k0)+'.p', 'wb'))
    pkl.dump(Y, open( 'Figures data/QUEST/h_no_topo_Porosity_permeability_variation_data_Y'+str(phi0)+'-'+str(k0)+'.p', 'wb'))
    pkl.dump(grid_z, open( 'Figures data/QUEST/h_no_topo_Porosity_permeability_variation_data_P'+str(phi0)+'-'+str(k0)+'.p', 'wb'))

# %%
folder = 'QUEST - No topo/Outputs - Diffusion model/'

export_p(folder, Nt, Nx, Ny, Nz, List_t, AOI, Outline, phi0, k0)
export_h(folder, Nt, Nx, Ny, Nz, List_t, AOI, Outline, phi0, k0)
# Out:
# 100%|██████████| 3002/3002 [00:00<00:00, 1503977.62it/s]
# 100%|██████████| 3002/3002 [00:00<00:00, 1124223.27it/s]

# %% [markdown]
# # Export data for mechanical model

# %%
# xmax = Outline[1][0]
# xmin = Outline[0][0]
ymax = Outline[2][1]
ymin = Outline[0][1]

XMesh = [] ; YMesh = []
for i in range(54):
    XMesh_tamp = [xmin+(xmax-xmin)*j/49 for j in range(50)]
    XMesh.append(XMesh_tamp)

for i in range(54):
    YMesh_tamp = [ymin+(ymax-ymin)*i/53 for j in range(50)]
    YMesh.append(YMesh_tamp)

X_, Y_ = np.meshgrid(np.array(XMesh)[0], np.array(YMesh)[:,0])
Thick = griddata(H_points, H_field, (X_, Y_), method='linear')
Depth = griddata(depth_points, depth_field, (X_, Y_), method='linear')

# Export RES
dRES = {'Depth':Depth, 'Thickness': Thick}
with open(output_folder + 'RES.p', 'wb') as handle: pickle.dump(dRES, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# Export X and Y coordinates
pickle.dump(np.array(XMesh), open(output_folder + 'X.p', 'wb')) ; pickle.dump(np.array(YMesh), open(output_folder + 'Y.p', 'wb'))

# Export Outline
Xcoordinates1 = np.linspace(xmin, xmin, 1000)
Xcoordinates2 = np.linspace(xmin, xmax, 1000)
Xcoordinates3 = np.linspace(xmax, xmax, 1000)
Xcoordinates4 = np.linspace(xmax, xmin, 1000)

Ycoordinates1 = np.linspace(ymin, ymax, 1000)
Ycoordinates2 = np.linspace(ymax, ymax, 1000)
Ycoordinates3 = np.linspace(ymax, ymin, 1000)
Ycoordinates4 = np.linspace(ymin, ymin, 1000)

dOutline = {'X': np.concatenate((Xcoordinates1,Xcoordinates2,Xcoordinates3,Xcoordinates4)), 'Y':np.concatenate((Ycoordinates1,Ycoordinates2,Ycoordinates3,Ycoordinates4))}
dfOutline = pd.DataFrame(data=dOutline)

with open(output_folder + 'Outline.p', 'wb') as handle: pickle.dump(dfOutline, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Export MESH
np.save(output_folder +'MESH.npy', np.array(mesh.coordinates()))

#Export thickness and depth

pickle.dump(np.array(H_points), open(output_folder + 'H_points.npy', 'wb'))
pickle.dump(np.array(H_field), open(output_folder + 'H_field.npy', 'wb'))
pickle.dump(np.array(depth_points), open(output_folder + 'Depth_points.npy', 'wb'))
pickle.dump(np.array(depth_field), open(output_folder + 'Depth_field.npy', 'wb'))
    
# Export data for mechanical model in folder 'output/'
# extract_pressure_list(folder_input, folder_output, Nt)
