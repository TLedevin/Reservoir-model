# %% [markdown]
# # Import librairies

# %%
from dolfin import*

import os
import glob

import time
import numpy as np
import pickle

from pathlib import Path
import matplotlib.pyplot as plt
from colorama import Fore, Back, Style
from CoolProp.CoolProp import PropsSI
import pyproj
from pyproj import Transformer
from mshr import Polygon, generate_mesh

from Plot_functions import*
from Auxiliary_functions import *
from Auxiliary_class import*

# %% [markdown]
# # Initialize folders

# %%
# Initialize time
time0 = time.time()

# Initialize folders for results
input_folder = "QUEST - Topo/Inputs"
output_folder = "QUEST - Topo/Outputs - Diffusion model/"
figures_output = "QUEST - Topo/Figures"

if not os.path.exists(output_folder):
    os.mkdir(output_folder)
if not os.path.exists(output_folder + "/p"):
    os.mkdir(output_folder + "/p")
else:
    for fichier in glob.glob(os.path.join(output_folder + "/p", '*')):
        os.remove(fichier)

if not os.path.exists(output_folder + "/h"):
    os.mkdir(output_folder + "/h")
else:
    for fichier in glob.glob(os.path.join(output_folder + "/h", '*')):
        os.remove(fichier)
    
if not os.path.exists(figures_output):
    os.mkdir(figures_output)

# %% [markdown]
# # Extract QUEST reservoir data

# %%
# Extract Quest data
df_PCS = pd.read_excel(os.path.join(input_folder, 'Quest, LCS, PCS.xlsx'), sheet_name='Pre-Cambrian')

# Convert GPS coordinates in UTM format
wgs84 = pyproj.CRS("EPSG:4326")
utm = pyproj.CRS("EPSG:26712")
transformer = Transformer.from_crs(wgs84, utm)
def convert_to_cartesian(longitude, latitude):
    x, y = transformer.transform(latitude, longitude)
    return x, y
df_PCS['X'], df_PCS['Y'] = zip(*df_PCS.apply(lambda row: convert_to_cartesian(-row['Long'], row['Lat']), axis=1))

# Area Of Interest coordinates
df_AOI = pd.read_csv(os.path.join(input_folder, 'AOI.csv'), sep=';', names=['Long', 'Lat'])
df_AOI['X'], df_AOI['Y'] = zip(*df_AOI.apply(lambda row: convert_to_cartesian(-row['Long'], row['Lat']), axis=1))
AOI = [[df_AOI['X'][ind], df_AOI['Y'][ind]] for ind in df_AOI.index]

x_min = np.min(df_AOI['X']) ; x_max = np.max(df_AOI['X'])
y_min = np.min(df_AOI['Y']) ; y_max = np.max(df_AOI['Y'])
xmin = x_min - 0.1*(x_max-x_min) ; xmax = x_max + 0.1*(x_max-x_min)
ymin = y_min - 0.1*(y_max-y_min) ; ymax = y_max + 0.1*(y_max-y_min)
Outline = [Point(xmin,ymin), Point(xmax,ymin), Point(xmax,ymax), Point(xmin,ymax), Point(xmin,ymin)]
Outline_array = np.array([[point[0], point[1]] for point in Outline])

# %% [markdown]
# # Model parameters

# %%
# General parameters
Temp = 70 # C # Temperature of the reservoir
Temp += 273.15 # K
p_ref = 2.0*1e7 # Pa # pressure reference (must be close to the pressure engaged in the reservoir)
p_extrem = 2.5*1e7
g = 9.81 # m.s-2
H0 = 47 # m # Thickness of the reservoir

# Depth of the reservoir. We initialize the depth using values of depth at some points.
# The field is then interpolated.
depth_points = []
depth_field = []
# Warning: depth values must be negative
for ind in df_PCS.index:
    if xmin<df_PCS['X'][ind]<xmax and ymin<df_PCS['Y'][ind]<ymax:
        depth_points.append([df_PCS['X'][ind], df_PCS['Y'][ind]])
        depth_field.append(df_PCS['Depth_PCS'][ind]+H0)
        # depth_field.append(-1400) # For flat reservoir
depth_points = np.array(depth_points)
depth_field = np.array(depth_field)

# Thickness of the reservoir. Same procedure than depth.
H_points = np.array(depth_points)
H_field = np.array([H0 for ind in range(len(H_points))])

# Reservoir physical parameters : permeability and porosity. Same procedure than thickness.
k0 = 1e-12 # m2
k_points = np.array([[xmin, xmax], [xmax, ymax], [xmin, ymin], [xmax, ymin]])
k_field = np.array([k0, k0, k0, k0])

phi0 = 0.3
phi_points = np.array([[xmin, xmax], [xmax, ymax], [xmin, ymin], [xmax, ymin]])
phi_field = np.array([phi0, phi0, phi0, phi0])

# Rock compressiblity. Has a small impact on results.
cr = 3e-11 # Pa-1

# Gas. Parameters calculated with CoolProp.
rho_g0 = PropsSI('D', 'T', Temp, 'P', p_ref, 'CO2') # kg.m-3 # density of gas
cg = PropsSI('ISOTHERMAL_COMPRESSIBILITY', 'T', Temp, 'P', p_ref, 'CO2') # Pa-1 # gas compressibility
mug0 = PropsSI('V', 'T', Temp, 'P', p_ref, 'CO2') # Pa.s # viscosity of gas
mug1 = PropsSI('V', 'T', Temp, 'P', p_extrem, 'CO2')
cvg = (mug1-mug0)/(p_extrem-p_ref)
krg = 1 # m2 # Relative permeability of gas in gas region
sg = 0.8 # saturation of gas in the gas region
def rho_g(p): return(rho_g0*(1+cg*(p-p_ref))) # Density profile
def mug(p): return(mug0*(1+cvg*(p-p_ref))) # Viscosity profile

# Water. Parameters calculated with CoolProp.
rho_w0 = PropsSI('D', 'T', Temp, 'P', p_ref, 'WATER') # kg.m-3 # density of water
cw = PropsSI('ISOTHERMAL_COMPRESSIBILITY', 'T', Temp, 'P', p_ref, 'WATER') # Pa-1 # water compressibility
muw0 = PropsSI('V', 'T', Temp, 'P', p_ref, 'WATER') # Pa.s # viscosity of water
muw1 = PropsSI('V', 'T', Temp, 'P', p_extrem, 'WATER')
cvw = (muw1-muw0)/(p_extrem-p_ref)
krw = 1 # m2 # Relative permeability of water
def rho_w(p): return(rho_w0*(1+cw*(p-p_ref))) # Density profile
def muw(p): return(muw0*(1+cvw*(p-p_ref))) # Viscosity profile

# Steps parameter
minute = 60 # s
hour = 60*minute
day = 24*hour
year = 365*day

dt = 1*minute
dt_max = 60*day
T_tot = 10*year # Simulation stopped at T_tot (even if the injection scenario is longer)

# %% [markdown]
# # Sources

# %%
Sources_g = []
# [location, [rates] in kg.s-1, [Times of operation]]
# Total amount of gas stored per year = 1.08 Mt
Rate_per_well = 1.08e9/365/24/3600/3 # convert to kg.s-1 and divide by 3
points_wells = [Point(370705.4800,5997747.3900), Point(367400,6001000), Point(376800,5994400)]
for point in points_wells:
    Sources_g.append([point, [Rate_per_well], [[5*year, 10*year]]])

sigma = 100 # m # source term standard deviation

# %% [markdown]
# # Meshgrid and model settings

# %%
# Form compiler options
parameters["form_compiler"]["optimize"]     = True
parameters["form_compiler"]["cpp_optimize"] = True
PETScOptions.set("pc_hypre_boomeramg_strong_threshold", .25)
PETScOptions.set("pc_hypre_boomeramg_truncfactor", 0.0)

# Create mesh and build function space
domain = Polygon(Outline)
Nm = 30 # define the global mesh fineness
Nhr = 1 # define the fineness of the mesh around the hydraulic radius of each well
radius1 = 2000 # The meshgrid will be refined Nhr times inside circles of radius=radius1, centered in well locations1
Nst = 4 # define the fineness of the mesh around each source
radius2 = 600 # The meshgrid will be refined Nhr times inside circles of radius=radius1, centered in well locations1
        # Source term will always be at least as accurate as hydraulic radius. We add Nst degrees of accuracy.

# mesh = create_mesh(domain, Nm, Nhr, Nst, Sources_g, sigma, T_tot, phi0, sg, rho_g0, H0)
mesh = generate_mesh(domain, Nm)
mesh = precise_mesh(mesh, points_wells, Nhr, radius1)
mesh = precise_mesh(mesh, points_wells, Nst, radius2)

print('Number of cells = '+str(mesh.num_cells()))
print(mesh.hmin())
print(mesh.hmax())

P1 = FiniteElement('Lagrange', triangle, 1)
ME = FunctionSpace(mesh, P1*P1)
ME1 = FunctionSpace(mesh, P1)
ME2=VectorFunctionSpace(mesh, "DG", 0)

fig = plt.figure(figsize=(6,6))
# plot_wells(Sources_g) # plot wells (red dots).

plot(mesh)
ax = plt.gca()
plot_AOI(ax, AOI, 'red')
plt.savefig(os.path.join(figures_output, 'QUEST_mesh_reservoir.png'), dpi=300)
# Out:
# Number of cells = 5870
# 60.9718523384101
# 3333.735283499833

# %% [markdown]
# # Initial conditions

# %% [markdown]
# #### Prepare functions and define initial conditions

# %%
# Define trial and test functions
du  = TrialFunction(ME)
v  = TestFunction(ME)

# Define functions
u   = Function(ME)  # current solution
u0  = Function(ME)  # solution from previous converged step

# Split mixed functions
dp, dh = split(du)
p,  h  = split(u)
p0, h0 = split(u0)
v_h, v_p = split(v)

# %% [markdown]
# #### Interpolate initial conditions

# %%
Coords = ME1.tabulate_dof_coordinates() # Coordinates of the mesh

# All the data are interpolated using : Radial basis function interpolation (RBF).
# Initial pressure
p_0 = 204.65e5 # Pa
p_points = np.array([[xmin, ymax], [xmax, ymax],
                     [xmin, ymin], [xmax, ymin]])
p_field = np.array([p_0, p_0,
                    p_0, p_0])
p_init = griddata(p_points, p_field, Coords, method='linear') # Linear interpolation

# Initial thickness of gas
h_0 = 0 # m
h_points = np.array([[xmin, ymax], [xmax, ymax],
                     [xmin, ymin], [xmax, ymin]])
h_field = np.array([h_0, h_0,
                    h_0, h_0])
h_init = griddata(h_points, h_field, Coords, method='linear')  # Linear interpolation

# Now that we have the mesh, we can interpolate H, phi and k.
H = H_function(H_points, H_field.flatten(), ME1, 'RBF')
k = k_function(k_points, k_field.flatten(), ME1, 'RBF')
phi = phi_function(phi_points, phi_field.flatten(), ME1, 'RBF')
depth = depth_function(depth_points, depth_field.flatten(), ME1, 'RBF')

print('Removing nan values...')
for i in tqdm(range(len(Coords))):
    if np.isnan(H.vector().get_local()[i]): H.vector().get_local()[i] = np.nanmean(Hf.vector().get_local())
    if np.isnan(p_init[i]) and not np.isnan(p_init[i-1]): p_init[i] = p_init[i-1]
    elif np.isnan(p_init[i]): p_init[i] = p_0
    if np.isnan(h_init[i]) : h_init[i] = h_0
print('...removed')

print('Interpolating initial conditions...')
u_init = InitialConditions(p_init, h_init, Coords, ME1)
u.interpolate(u_init)
u0.interpolate(u_init)
print('... interpolated')

# Display real injected mass. This function can be used to verify the amount of the fluid which is injected at a given time.
t_inj = 10*day # Time when we want to verify the injected mass (mass flow rate).
s_g_ = Function(ME1) ; s_g_.interpolate(s(Sources_g, t_inj, ME1, sigma))
print('Injected mass at t = ' + day_format(t_inj) + ' : ' + str(assemble(s_g_*dx)) + ' kg.s-1')

# Plot
plot_initial_conditions(figures_output, Sources_g, u, h_field, Outline_array)
plot_AOI(plt.gca(), AOI, 'black')
plot_extraction_data(figures_output, Sources_g, T_tot)
plot_phi_k_H_depth(figures_output, Sources_g, Outline_array, k, H, phi, depth)
plot_AOI(plt.gca(), AOI, 'black')
# Out:
# Removing nan values...
# 100%|██████████| 3002/3002 [00:00<00:00, 58601.80it/s]
# ...removed
# Interpolating initial conditions...
# ... interpolated
# Injected mass at t = 10.0 days : 0.0 kg.s-1

# %% [markdown]
# # Calculating the topography of the reservoir

# %%
gradi = grad(depth+H)
gradient = project(gradi,ME2) 
gradient_values = gradient.compute_vertex_values(mesh) #to get all the data  from gradient

# Calcul for the gradient in the X direction
gradient_X = []
for i in range(0,int(len(gradient_values)/2)):
    gradient_X.append(gradient_values[i])

# Calcul for the gradient in the Y direction
gradient_Y = []
for i in range(int(len(gradient_values)/2),len(gradient_values)):
    gradient_Y.append(gradient_values[i])

# Creation of a panda fram
panda = pd.DataFrame({'Coord X':mesh.coordinates()[:,0],'Coord Y':mesh.coordinates()[:,1],'Grad X':gradient_X[:],'Grad Y':gradient_Y[:] })

# Calcul of the norme of the gradient
Norme=[]
for i in range(len(panda['Grad Y'])):
    Norme_numpy = math.sqrt(panda['Grad X'][i]**2+panda['Grad Y'][i]**2)
    Norme.append(Norme_numpy)
panda['Norme Gradient']=Norme

# Transposition du gradient; norme(gradient)=angle
angle_Points = np.array(list(zip(panda['Coord X'], panda['Coord Y'])))

x_mesh = np.linspace(xmin, xmax, num=100)  # Vous pouvez ajuster le nombre de points de la grille si nécessaire
y_mesh = np.linspace(ymin, ymax, num=100)
X_mesh, Y_mesh = np.meshgrid(x_mesh, y_mesh)
angle_rad_panda = griddata((panda['Coord X'],panda['Coord Y']),panda['Norme Gradient'], (X_mesh,Y_mesh),method='linear')

# Plot de l'angle
plt.figure(figsize=(7, 6))
plt.scatter(X_mesh,Y_mesh,c=angle_rad_panda, s=10)
plt.colorbar()
plt.title('Value of the angle[rad]')
plt.xlabel('X[m]')
plt.ylabel('Y[m]')
angle_value=np.array(panda['Norme Gradient'])
ax = plt.gca()
plot_AOI(ax, AOI, 'red')
angle_points = np.array(list(zip(panda['Coord X'], panda['Coord Y'])))
angle_rad = angle_function(angle_points, angle_value.flatten(), ME1, 'RBF')

# %% [markdown]
# # Boundary conditions

# %%
use_boundary = False

if use_boundary:
    u_bound = InitialConditions(p_init, h_init, Coords, ME1)

    def boundary_L(x, on_boundary):
        tol = 1000
        if on_boundary:
            for vertice in Outline_array:
                if near(x[0], vertice[0], tol) and near(x[1], vertice[1], tol):
                    return True
        return False

    bc = DirichletBC(ME, u_bound, boundary_L)
    bcs = [bc]
else:
    bcs = []

# %% [markdown]
# # Define problem

# %%
# Step in time
t = 0.0 # Initialize initial time
Nt = 0 # Initialize number of iterations
List_t = [t] # Create list of step times

problem = define_problem_topography(dt, t,
                                    Sources_g,
                                    ME1,
                                    H, phi, sg, g,
                                    rho_g, rho_w, rho_g0, rho_w0, mug, muw,
                                    cr, cg, cw,
                                    u, p, h, p0, h0, du,
                                    sigma,
                                    v_p, v_h,
                                    k, krg, krw, bcs, depth, angle_rad)

solver = NewtonSolver()
solver.parameters["linear_solver"] = "gmres" # mumps
solver.parameters["convergence_criterion"] = "incremental" # "residual"
solver.parameters["relative_tolerance"] = 1e-8
solver.parameters["absolute_tolerance"] = 1e-7
solver.parameters["maximum_iterations"] = 20

# %% [markdown]
# # Main loop (data saved in the main loop)

# %%
# Prepare folder to save results
file_p = File (output_folder + "/p" + "/output_p.pvd")
file_h = File (output_folder + "/h" + "/output_h.pvd")
file_p << u.split()[0] ; file_h << u.split()[1]
file_H = File (output_folder + "/H.pvd") ; file_H << H

Mass_found0 = assemble(h*rho_g(p)*phi*dx)*sg # Initial CO2 mass found
List_err = [0] # Create list to save relative difference of CO2 mass (between injected and found)
time0 = time.time() # Save current time to calculate loop duration

while (t < T_tot):
    Nt += 1
    
    print(Fore.BLUE+'Iteration ' + str(Nt) + ' : t = '+day_format(t)+' ------> t = '+day_format(t+dt) + ' (dt = ' + day_format(dt) + ')' )
    print(Style.RESET_ALL)
    t += dt ; List_t.append(t)
    
    u0.vector()[:] = u.vector()[:] # Initialize new value
    (no_of_iterations,converged) = solver.solve(problem, u.vector()) # Solve problem
    Mass_found = assemble(h*rho_g(p)*phi*dx)*sg
    Expected_injected_mass = injected_mass(t, Sources_g)
    if no_of_iterations > 10 : dt /= 16
    elif no_of_iterations > 4 : dt /= 2
    elif dt<dt_max/2 : dt *= 2
    
    # Redefine the problem with new values
    problem = define_problem_topography(dt, t,
                                        Sources_g,
                                        ME1,
                                        H, phi, sg, g,
                                        rho_g, rho_w, rho_g0, rho_w0, mug, muw,
                                        cr, cg, cw,
                                        u, p, h, p0, h0, du,
                                        sigma,
                                        v_p, v_h,
                                        k, krg, krw, bcs, depth, angle_rad)
    
    file_p << u.split()[0]
    file_h << u.split()[1]
    
    print(Fore.GREEN + 'Expected injected mass at t = ' + day_format(t) + " : " + str(Expected_injected_mass*1e-9) + ' Mt')
    print(Fore.GREEN + 'Injected mass found at t = ' + day_format(t) + " : " + str((Mass_found-Mass_found0)*1e-9) + ' Mt (cumulative)')
    if Expected_injected_mass != 0:
        print(Fore.GREEN + 'Relative difference = ' + str(100*abs((Expected_injected_mass-Mass_found+Mass_found0)/Expected_injected_mass)) + ' %')
        List_err.append(abs((Expected_injected_mass-Mass_found+Mass_found0)/Expected_injected_mass))
    else:
        List_err.append(0)

timef = time.time()
# Out:
# Iteration 1 : t = 0 s ------> t = 1 min (dt = 1 min)
#
# Newton iteration 0: r (abs) = 1.007e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.715e-03 (tol = 1.000e-07) r (rel) = 5.677e-06 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.013e-08 (tol = 1.000e-07) r (rel) = 6.967e-11 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 13 linear solver iterations.
# Expected injected mass at t = 1 min : 0.0 Mt
# Injected mass found at t = 1 min : 0.0 Mt (cumulative)
# Iteration 2 : t = 1 min ------> t = 3 min (dt = 2 min)
#
# Newton iteration 0: r (abs) = 2.000e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.706e-02 (tol = 1.000e-07) r (rel) = 8.532e-06 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.213e-08 (tol = 1.000e-07) r (rel) = 3.607e-11 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 14 linear solver iterations.
# Expected injected mass at t = 3 min : 0.0 Mt
# Injected mass found at t = 3 min : 0.0 Mt (cumulative)
# Iteration 3 : t = 3 min ------> t = 7 min (dt = 4 min)
#
# Newton iteration 0: r (abs) = 3.955e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.389e-02 (tol = 1.000e-07) r (rel) = 8.568e-06 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.388e-07 (tol = 1.000e-07) r (rel) = 3.510e-11 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 17 linear solver iterations.
# Expected injected mass at t = 7 min : 0.0 Mt
# Injected mass found at t = 7 min : 0.0 Mt (cumulative)
# Iteration 4 : t = 7 min ------> t = 15 min (dt = 8 min)
#
# Newton iteration 0: r (abs) = 7.747e+03 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.556e-02 (tol = 1.000e-07) r (rel) = 3.299e-06 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.604e-07 (tol = 1.000e-07) r (rel) = 2.070e-11 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 23 linear solver iterations.
# Expected injected mass at t = 15 min : 0.0 Mt
# Injected mass found at t = 15 min : 0.0 Mt (cumulative)
# Iteration 5 : t = 15 min ------> t = 31 min (dt = 16 min)
#
# Newton iteration 0: r (abs) = 1.489e+04 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.023e-01 (tol = 1.000e-07) r (rel) = 1.358e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.533e-06 (tol = 1.000e-07) r (rel) = 1.029e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 29 linear solver iterations.
# Expected injected mass at t = 31 min : 0.0 Mt
# Injected mass found at t = 31 min : 0.0 Mt (cumulative)
# Iteration 6 : t = 31 min ------> t = 1.0 h (dt = 32 min)
#
# Newton iteration 0: r (abs) = 2.773e+04 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.230e-01 (tol = 1.000e-07) r (rel) = 1.886e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.003e-06 (tol = 1.000e-07) r (rel) = 7.224e-11 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 38 linear solver iterations.
# Expected injected mass at t = 1.0 h : 0.0 Mt
# Injected mass found at t = 1.0 h : 0.0 Mt (cumulative)
# Iteration 7 : t = 1.0 h ------> t = 2.1 h (dt = 1.0 h)
#
# Newton iteration 0: r (abs) = 4.915e+04 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.513e+00 (tol = 1.000e-07) r (rel) = 3.079e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.812e-06 (tol = 1.000e-07) r (rel) = 1.386e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 49 linear solver iterations.
# Expected injected mass at t = 2.1 h : 0.0 Mt
# Injected mass found at t = 2.1 h : 0.0 Mt (cumulative)
# Iteration 8 : t = 2.1 h ------> t = 4.2 h (dt = 2.1 h)
#
# Newton iteration 0: r (abs) = 8.195e+04 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.809e+00 (tol = 1.000e-07) r (rel) = 3.428e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.315e-05 (tol = 1.000e-07) r (rel) = 4.045e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 59 linear solver iterations.
# Expected injected mass at t = 4.2 h : 0.0 Mt
# Injected mass found at t = 4.2 h : 0.0 Mt (cumulative)
# Iteration 9 : t = 4.2 h ------> t = 8.5 h (dt = 4.2 h)
#
# Newton iteration 0: r (abs) = 1.296e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.146e+00 (tol = 1.000e-07) r (rel) = 5.513e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.755e-05 (tol = 1.000e-07) r (rel) = 2.896e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 74 linear solver iterations.
# Expected injected mass at t = 8.5 h : 0.0 Mt
# Injected mass found at t = 8.5 h : 0.0 Mt (cumulative)
# Iteration 10 : t = 8.5 h ------> t = 17.0 h (dt = 8.5 h)
#
# Newton iteration 0: r (abs) = 2.007e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.345e+01 (tol = 1.000e-07) r (rel) = 6.698e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.210e-04 (tol = 1.000e-07) r (rel) = 6.030e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 86 linear solver iterations.
# Expected injected mass at t = 17.0 h : 0.0 Mt
# Injected mass found at t = 17.0 h : 0.0 Mt (cumulative)
# Iteration 11 : t = 17.0 h ------> t = 1.4 days (dt = 17.0 h)
#
# Newton iteration 0: r (abs) = 3.154e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.604e+01 (tol = 1.000e-07) r (rel) = 8.257e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.564e-04 (tol = 1.000e-07) r (rel) = 8.131e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 95 linear solver iterations.
# Expected injected mass at t = 1.4 days : 0.0 Mt
# Injected mass found at t = 1.4 days : 0.0 Mt (cumulative)
# Iteration 12 : t = 1.4 days ------> t = 2.8 days (dt = 1.4 days)
#
# Newton iteration 0: r (abs) = 5.096e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.990e+01 (tol = 1.000e-07) r (rel) = 9.793e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.569e-04 (tol = 1.000e-07) r (rel) = 1.682e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 95 linear solver iterations.
# Expected injected mass at t = 2.8 days : 0.0 Mt
# Injected mass found at t = 2.8 days : 0.0 Mt (cumulative)
# Iteration 13 : t = 2.8 days ------> t = 5.6 days (dt = 2.8 days)
#
# Newton iteration 0: r (abs) = 8.359e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.417e+01 (tol = 1.000e-07) r (rel) = 7.676e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.610e-03 (tol = 1.000e-07) r (rel) = 1.926e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 107 linear solver iterations.
# Expected injected mass at t = 5.6 days : 0.0 Mt
# Injected mass found at t = 5.6 days : 0.0 Mt (cumulative)
# Iteration 14 : t = 5.6 days ------> t = 11.3 days (dt = 5.6 days)
#
# Newton iteration 0: r (abs) = 1.365e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.025e+02 (tol = 1.000e-07) r (rel) = 7.510e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.469e-03 (tol = 1.000e-07) r (rel) = 2.542e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 125 linear solver iterations.
# Expected injected mass at t = 11.3 days : 0.0 Mt
# Injected mass found at t = 11.3 days : 0.0 Mt (cumulative)
# Iteration 15 : t = 11.3 days ------> t = 22.7 days (dt = 11.3 days)
#
# Newton iteration 0: r (abs) = 2.181e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.596e+02 (tol = 1.000e-07) r (rel) = 1.190e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.171e-03 (tol = 1.000e-07) r (rel) = 1.454e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 142 linear solver iterations.
# Expected injected mass at t = 22.7 days : 0.0 Mt
# Injected mass found at t = 22.7 days : 0.0 Mt (cumulative)
# Iteration 16 : t = 22.7 days ------> t = 45.5 days (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 3.381e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.583e+02 (tol = 1.000e-07) r (rel) = 1.356e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.239e-02 (tol = 1.000e-07) r (rel) = 3.664e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 132 linear solver iterations.
# Expected injected mass at t = 45.5 days : 0.0 Mt
# Injected mass found at t = 45.5 days : 0.0 Mt (cumulative)
# Iteration 17 : t = 45.5 days ------> t = 91.0 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 5.171e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.699e+02 (tol = 1.000e-07) r (rel) = 1.682e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.840e-02 (tol = 1.000e-07) r (rel) = 5.492e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 176 linear solver iterations.
# Expected injected mass at t = 91.0 days : 0.0 Mt
# Injected mass found at t = 91.0 days : 0.0 Mt (cumulative)
# Iteration 18 : t = 91.0 days ------> t = 136.5 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.401e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.241e+02 (tol = 1.000e-07) r (rel) = 9.637e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.134e-03 (tol = 1.000e-07) r (rel) = 2.076e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 186 linear solver iterations.
# Expected injected mass at t = 136.5 days : 0.0 Mt
# Injected mass found at t = 136.5 days : 0.0 Mt (cumulative)
# Iteration 19 : t = 136.5 days ------> t = 182.0 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.917e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.225e+02 (tol = 1.000e-07) r (rel) = 5.681e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.428e-03 (tol = 1.000e-07) r (rel) = 8.753e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 183 linear solver iterations.
# Expected injected mass at t = 182.0 days : 0.0 Mt
# Injected mass found at t = 182.0 days : 0.0 Mt (cumulative)
# Iteration 20 : t = 182.0 days ------> t = 227.5 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.545e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.309e+02 (tol = 1.000e-07) r (rel) = 9.334e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.213e-03 (tol = 1.000e-07) r (rel) = 1.752e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 174 linear solver iterations.
# Expected injected mass at t = 227.5 days : 0.0 Mt
# Injected mass found at t = 227.5 days : 0.0 Mt (cumulative)
# Iteration 21 : t = 227.5 days ------> t = 273.0 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.229e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.741e+02 (tol = 1.000e-07) r (rel) = 1.158e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.283e-03 (tol = 1.000e-07) r (rel) = 1.636e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 207 linear solver iterations.
# Expected injected mass at t = 273.0 days : 0.0 Mt
# Injected mass found at t = 273.0 days : 0.0 Mt (cumulative)
# Iteration 22 : t = 273.0 days ------> t = 318.5 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.948e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.622e+02 (tol = 1.000e-07) r (rel) = 1.229e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.753e-03 (tol = 1.000e-07) r (rel) = 1.273e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 172 linear solver iterations.
# Expected injected mass at t = 318.5 days : 0.0 Mt
# Injected mass found at t = 318.5 days : 0.0 Mt (cumulative)
# Iteration 23 : t = 318.5 days ------> t = 364.0 days (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.693e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.140e+02 (tol = 1.000e-07) r (rel) = 1.166e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 4.328e-03 (tol = 1.000e-07) r (rel) = 1.607e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 175 linear solver iterations.
# Expected injected mass at t = 364.0 days : 0.0 Mt
# Injected mass found at t = 364.0 days : 0.0 Mt (cumulative)
# Iteration 24 : t = 364.0 days ------> t = 1.12 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.461e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.960e+02 (tol = 1.000e-07) r (rel) = 1.203e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.982e-03 (tol = 1.000e-07) r (rel) = 1.618e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 198 linear solver iterations.
# Expected injected mass at t = 1.12 years : 0.0 Mt
# Injected mass found at t = 1.12 years : 0.0 Mt (cumulative)
# Iteration 25 : t = 1.12 years ------> t = 1.24 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.250e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.754e+02 (tol = 1.000e-07) r (rel) = 1.224e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.677e-03 (tol = 1.000e-07) r (rel) = 1.634e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 199 linear solver iterations.
# Expected injected mass at t = 1.24 years : 0.0 Mt
# Injected mass found at t = 1.24 years : 0.0 Mt (cumulative)
# Iteration 26 : t = 1.24 years ------> t = 1.37 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.058e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.539e+02 (tol = 1.000e-07) r (rel) = 1.234e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.219e-03 (tol = 1.000e-07) r (rel) = 1.564e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 199 linear solver iterations.
# Expected injected mass at t = 1.37 years : 0.0 Mt
# Injected mass found at t = 1.37 years : 0.0 Mt (cumulative)
# Iteration 27 : t = 1.37 years ------> t = 1.49 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.882e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.327e+02 (tol = 1.000e-07) r (rel) = 1.237e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.932e-03 (tol = 1.000e-07) r (rel) = 1.558e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 175 linear solver iterations.
# Expected injected mass at t = 1.49 years : 0.0 Mt
# Injected mass found at t = 1.49 years : 0.0 Mt (cumulative)
# Iteration 28 : t = 1.49 years ------> t = 1.62 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.722e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.125e+02 (tol = 1.000e-07) r (rel) = 1.234e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.542e-03 (tol = 1.000e-07) r (rel) = 1.476e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 185 linear solver iterations.
# Expected injected mass at t = 1.62 years : 0.0 Mt
# Injected mass found at t = 1.62 years : 0.0 Mt (cumulative)
# Iteration 29 : t = 1.62 years ------> t = 1.74 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.575e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.936e+02 (tol = 1.000e-07) r (rel) = 1.229e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.197e-03 (tol = 1.000e-07) r (rel) = 1.395e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 186 linear solver iterations.
# Expected injected mass at t = 1.74 years : 0.0 Mt
# Injected mass found at t = 1.74 years : 0.0 Mt (cumulative)
# Iteration 30 : t = 1.74 years ------> t = 1.87 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.441e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.760e+02 (tol = 1.000e-07) r (rel) = 1.221e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.992e-03 (tol = 1.000e-07) r (rel) = 1.382e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 171 linear solver iterations.
# Expected injected mass at t = 1.87 years : 0.0 Mt
# Injected mass found at t = 1.87 years : 0.0 Mt (cumulative)
# Iteration 31 : t = 1.87 years ------> t = 1.99 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.319e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.793e+02 (tol = 1.000e-07) r (rel) = 1.360e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.957e-03 (tol = 1.000e-07) r (rel) = 1.483e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 165 linear solver iterations.
# Expected injected mass at t = 1.99 years : 0.0 Mt
# Injected mass found at t = 1.99 years : 0.0 Mt (cumulative)
# Iteration 32 : t = 1.99 years ------> t = 2.11 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.208e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.623e+02 (tol = 1.000e-07) r (rel) = 1.344e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.110e-03 (tol = 1.000e-07) r (rel) = 9.194e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 188 linear solver iterations.
# Expected injected mass at t = 2.11 years : 0.0 Mt
# Injected mass found at t = 2.11 years : 0.0 Mt (cumulative)
# Iteration 33 : t = 2.11 years ------> t = 2.24 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.106e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.466e+02 (tol = 1.000e-07) r (rel) = 1.326e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.871e-04 (tol = 1.000e-07) r (rel) = 3.501e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 185 linear solver iterations.
# Expected injected mass at t = 2.24 years : 0.0 Mt
# Injected mass found at t = 2.24 years : 0.0 Mt (cumulative)
# Iteration 34 : t = 2.24 years ------> t = 2.36 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.013e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.322e+02 (tol = 1.000e-07) r (rel) = 1.306e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 4.989e-04 (tol = 1.000e-07) r (rel) = 4.926e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 185 linear solver iterations.
# Expected injected mass at t = 2.36 years : 0.0 Mt
# Injected mass found at t = 2.36 years : 0.0 Mt (cumulative)
# Iteration 35 : t = 2.36 years ------> t = 2.49 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 9.278e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.190e+02 (tol = 1.000e-07) r (rel) = 1.283e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.990e-04 (tol = 1.000e-07) r (rel) = 8.612e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 181 linear solver iterations.
# Expected injected mass at t = 2.49 years : 0.0 Mt
# Injected mass found at t = 2.49 years : 0.0 Mt (cumulative)
# Iteration 36 : t = 2.49 years ------> t = 2.61 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 8.501e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.069e+02 (tol = 1.000e-07) r (rel) = 1.258e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.465e-04 (tol = 1.000e-07) r (rel) = 9.957e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 162 linear solver iterations.
# Expected injected mass at t = 2.61 years : 0.0 Mt
# Injected mass found at t = 2.61 years : 0.0 Mt (cumulative)
# Iteration 37 : t = 2.61 years ------> t = 2.74 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 7.792e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 9.585e+01 (tol = 1.000e-07) r (rel) = 1.230e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.390e-04 (tol = 1.000e-07) r (rel) = 1.077e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 172 linear solver iterations.
# Expected injected mass at t = 2.74 years : 0.0 Mt
# Injected mass found at t = 2.74 years : 0.0 Mt (cumulative)
# Iteration 38 : t = 2.74 years ------> t = 2.86 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 7.143e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 9.300e+01 (tol = 1.000e-07) r (rel) = 1.302e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.911e-04 (tol = 1.000e-07) r (rel) = 1.108e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 172 linear solver iterations.
# Expected injected mass at t = 2.86 years : 0.0 Mt
# Injected mass found at t = 2.86 years : 0.0 Mt (cumulative)
# Iteration 39 : t = 2.86 years ------> t = 2.99 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 6.550e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.296e+01 (tol = 1.000e-07) r (rel) = 1.267e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.790e-04 (tol = 1.000e-07) r (rel) = 1.037e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 172 linear solver iterations.
# Expected injected mass at t = 2.99 years : 0.0 Mt
# Injected mass found at t = 2.99 years : 0.0 Mt (cumulative)
# Iteration 40 : t = 2.99 years ------> t = 3.11 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 6.007e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.379e+01 (tol = 1.000e-07) r (rel) = 1.228e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.354e-04 (tol = 1.000e-07) r (rel) = 1.391e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 172 linear solver iterations.
# Expected injected mass at t = 3.11 years : 0.0 Mt
# Injected mass found at t = 3.11 years : 0.0 Mt (cumulative)
# Iteration 41 : t = 3.11 years ------> t = 3.24 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 5.511e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.538e+01 (tol = 1.000e-07) r (rel) = 1.186e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.645e-04 (tol = 1.000e-07) r (rel) = 1.206e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 171 linear solver iterations.
# Expected injected mass at t = 3.24 years : 0.0 Mt
# Injected mass found at t = 3.24 years : 0.0 Mt (cumulative)
# Iteration 42 : t = 3.24 years ------> t = 3.36 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 5.057e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.239e+01 (tol = 1.000e-07) r (rel) = 1.234e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.060e-04 (tol = 1.000e-07) r (rel) = 1.396e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 170 linear solver iterations.
# Expected injected mass at t = 3.36 years : 0.0 Mt
# Injected mass found at t = 3.36 years : 0.0 Mt (cumulative)
# Iteration 43 : t = 3.36 years ------> t = 3.49 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.642e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.486e+01 (tol = 1.000e-07) r (rel) = 1.182e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.681e-04 (tol = 1.000e-07) r (rel) = 7.930e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 173 linear solver iterations.
# Expected injected mass at t = 3.49 years : 0.0 Mt
# Injected mass found at t = 3.49 years : 0.0 Mt (cumulative)
# Iteration 44 : t = 3.49 years ------> t = 3.61 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.261e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.794e+01 (tol = 1.000e-07) r (rel) = 1.125e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.871e-04 (tol = 1.000e-07) r (rel) = 9.083e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 190 linear solver iterations.
# Expected injected mass at t = 3.61 years : 0.0 Mt
# Injected mass found at t = 3.61 years : 0.0 Mt (cumulative)
# Iteration 45 : t = 3.61 years ------> t = 3.74 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.913e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.169e+01 (tol = 1.000e-07) r (rel) = 1.065e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.859e-04 (tol = 1.000e-07) r (rel) = 7.306e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 198 linear solver iterations.
# Expected injected mass at t = 3.74 years : 0.0 Mt
# Injected mass found at t = 3.74 years : 0.0 Mt (cumulative)
# Iteration 46 : t = 3.74 years ------> t = 3.86 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.594e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.611e+01 (tol = 1.000e-07) r (rel) = 1.005e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.834e-04 (tol = 1.000e-07) r (rel) = 1.067e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 199 linear solver iterations.
# Expected injected mass at t = 3.86 years : 0.0 Mt
# Injected mass found at t = 3.86 years : 0.0 Mt (cumulative)
# Iteration 47 : t = 3.86 years ------> t = 3.99 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.302e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.612e+01 (tol = 1.000e-07) r (rel) = 1.094e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.904e-04 (tol = 1.000e-07) r (rel) = 1.182e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 194 linear solver iterations.
# Expected injected mass at t = 3.99 years : 0.0 Mt
# Injected mass found at t = 3.99 years : 0.0 Mt (cumulative)
# Iteration 48 : t = 3.99 years ------> t = 4.11 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.035e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.087e+01 (tol = 1.000e-07) r (rel) = 1.017e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.522e-04 (tol = 1.000e-07) r (rel) = 1.161e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 205 linear solver iterations.
# Expected injected mass at t = 4.11 years : 0.0 Mt
# Injected mass found at t = 4.11 years : 0.0 Mt (cumulative)
# Iteration 49 : t = 4.11 years ------> t = 4.23 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.789e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.655e+01 (tol = 1.000e-07) r (rel) = 9.517e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.621e-04 (tol = 1.000e-07) r (rel) = 9.395e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 208 linear solver iterations.
# Expected injected mass at t = 4.23 years : 0.0 Mt
# Injected mass found at t = 4.23 years : 0.0 Mt (cumulative)
# Iteration 50 : t = 4.23 years ------> t = 4.36 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.565e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.246e+01 (tol = 1.000e-07) r (rel) = 8.758e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.664e-04 (tol = 1.000e-07) r (rel) = 1.039e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 208 linear solver iterations.
# Expected injected mass at t = 4.36 years : 0.0 Mt
# Injected mass found at t = 4.36 years : 0.0 Mt (cumulative)
# Iteration 51 : t = 4.36 years ------> t = 4.48 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.358e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.878e+01 (tol = 1.000e-07) r (rel) = 7.964e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.516e-04 (tol = 1.000e-07) r (rel) = 1.067e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 208 linear solver iterations.
# Expected injected mass at t = 4.48 years : 0.0 Mt
# Injected mass found at t = 4.48 years : 0.0 Mt (cumulative)
# Iteration 52 : t = 4.48 years ------> t = 4.61 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.169e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.563e+01 (tol = 1.000e-07) r (rel) = 7.207e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.186e-04 (tol = 1.000e-07) r (rel) = 1.008e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 206 linear solver iterations.
# Expected injected mass at t = 4.61 years : 0.0 Mt
# Injected mass found at t = 4.61 years : 0.0 Mt (cumulative)
# Iteration 53 : t = 4.61 years ------> t = 4.73 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.996e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.326e+01 (tol = 1.000e-07) r (rel) = 6.645e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.068e-04 (tol = 1.000e-07) r (rel) = 1.036e-09 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 185 linear solver iterations.
# Expected injected mass at t = 4.73 years : 0.0 Mt
# Injected mass found at t = 4.73 years : 0.0 Mt (cumulative)
# Iteration 54 : t = 4.73 years ------> t = 4.86 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.837e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.179e+01 (tol = 1.000e-07) r (rel) = 6.417e-05 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.677e-04 (tol = 1.000e-07) r (rel) = 9.133e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 172 linear solver iterations.
# Expected injected mass at t = 4.86 years : 0.0 Mt
# Injected mass found at t = 4.86 years : 0.0 Mt (cumulative)
# Iteration 55 : t = 4.86 years ------> t = 4.98 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.691e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.910e+01 (tol = 1.000e-07) r (rel) = 1.130e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.431e-04 (tol = 1.000e-07) r (rel) = 8.467e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 168 linear solver iterations.
# Expected injected mass at t = 4.98 years : 0.0 Mt
# Injected mass found at t = 4.98 years : 0.0 Mt (cumulative)
# Iteration 56 : t = 4.98 years ------> t = 5.11 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 1.556e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.729e+01 (tol = 1.000e-07) r (rel) = 1.111e-04 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.368e-04 (tol = 1.000e-07) r (rel) = 8.790e-10 (tol = 1.000e-08)
# Newton solver finished in 3 iterations and 150 linear solver iterations.
# Expected injected mass at t = 5.11 years : 0.12118150684931508 Mt
# Injected mass found at t = 5.11 years : 0.0 Mt (cumulative)
# Relative difference = 100.0 %
# Iteration 57 : t = 5.11 years ------> t = 5.23 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.423e+06 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.535e+05 (tol = 1.000e-07) r (rel) = 4.485e-02 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.156e+04 (tol = 1.000e-07) r (rel) = 9.220e-03 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.034e+03 (tol = 1.000e-07) r (rel) = 5.941e-04 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 1.277e+01 (tol = 1.000e-07) r (rel) = 3.731e-06 (tol = 1.000e-08)
# Newton iteration 5: r (abs) = 3.854e-03 (tol = 1.000e-07) r (rel) = 1.126e-09 (tol = 1.000e-08)
# Newton solver finished in 6 iterations and 233 linear solver iterations.
# Expected injected mass at t = 5.23 years : 0.2558445205479452 Mt
# Injected mass found at t = 5.23 years : 0.1345471151017022 Mt (cumulative)
# Relative difference = 47.41059342856315 %
# Iteration 58 : t = 5.23 years ------> t = 5.29 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 6.593e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.227e+03 (tol = 1.000e-07) r (rel) = 6.411e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.130e+00 (tol = 1.000e-07) r (rel) = 3.231e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.087e-03 (tol = 1.000e-07) r (rel) = 1.648e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 188 linear solver iterations.
# Expected injected mass at t = 5.29 years : 0.32317602739726026 Mt
# Injected mass found at t = 5.29 years : 0.20215535619160976 Mt (cumulative)
# Relative difference = 37.447292170866156 %
# Iteration 59 : t = 5.29 years ------> t = 5.42 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 7.597e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.590e+03 (tol = 1.000e-07) r (rel) = 9.990e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.900e+01 (tol = 1.000e-07) r (rel) = 5.133e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.220e-02 (tol = 1.000e-07) r (rel) = 2.922e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 2.387e-06 (tol = 1.000e-07) r (rel) = 3.141e-12 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 258 linear solver iterations.
# Expected injected mass at t = 5.42 years : 0.4578390410958904 Mt
# Injected mass found at t = 5.42 years : 0.33727379172409083 Mt (cumulative)
# Relative difference = 26.333544881452838 %
# Iteration 60 : t = 5.42 years ------> t = 5.48 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 3.089e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.871e+03 (tol = 1.000e-07) r (rel) = 6.058e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.493e-01 (tol = 1.000e-07) r (rel) = 1.778e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.674e-04 (tol = 1.000e-07) r (rel) = 8.658e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 200 linear solver iterations.
# Expected injected mass at t = 5.48 years : 0.5251705479452055 Mt
# Injected mass found at t = 5.48 years : 0.405199544760872 Mt (cumulative)
# Relative difference = 22.84419864246669 %
# Iteration 61 : t = 5.48 years ------> t = 5.61 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 4.841e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 4.512e+03 (tol = 1.000e-07) r (rel) = 9.322e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.729e+01 (tol = 1.000e-07) r (rel) = 3.573e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.117e-02 (tol = 1.000e-07) r (rel) = 2.308e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 1.148e-06 (tol = 1.000e-07) r (rel) = 2.371e-12 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 255 linear solver iterations.
# Expected injected mass at t = 5.61 years : 0.6598335616438356 Mt
# Injected mass found at t = 5.61 years : 0.5405901677641162 Mt (cumulative)
# Relative difference = 18.071738209655436 %
# Iteration 62 : t = 5.61 years ------> t = 5.67 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 2.187e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.208e+03 (tol = 1.000e-07) r (rel) = 5.524e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.205e-01 (tol = 1.000e-07) r (rel) = 1.466e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 8.505e-05 (tol = 1.000e-07) r (rel) = 3.889e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 209 linear solver iterations.
# Expected injected mass at t = 5.67 years : 0.7271650684931508 Mt
# Injected mass found at t = 5.67 years : 0.6085493843284289 Mt (cumulative)
# Relative difference = 16.312071261965343 %
# Iteration 63 : t = 5.67 years ------> t = 5.79 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.823e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 3.131e+03 (tol = 1.000e-07) r (rel) = 8.190e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.410e+00 (tol = 1.000e-07) r (rel) = 2.461e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.785e-03 (tol = 1.000e-07) r (rel) = 1.513e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 3.733e-07 (tol = 1.000e-07) r (rel) = 9.763e-13 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 240 linear solver iterations.
# Expected injected mass at t = 5.79 years : 0.8618280821917809 Mt
# Injected mass found at t = 5.79 years : 0.743972020465746 Mt (cumulative)
# Relative difference = 13.675124327151899 %
# Iteration 64 : t = 5.79 years ------> t = 5.86 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 1.804e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.898e+02 (tol = 1.000e-07) r (rel) = 4.932e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.408e-01 (tol = 1.000e-07) r (rel) = 1.335e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 8.426e-05 (tol = 1.000e-07) r (rel) = 4.670e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 199 linear solver iterations.
# Expected injected mass at t = 5.86 years : 0.9291595890410961 Mt
# Injected mass found at t = 5.86 years : 0.8121038737105062 Mt (cumulative)
# Relative difference = 12.598020481217098 %
# Iteration 65 : t = 5.86 years ------> t = 5.98 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.328e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 2.399e+03 (tol = 1.000e-07) r (rel) = 7.208e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.934e+00 (tol = 1.000e-07) r (rel) = 1.783e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.972e-03 (tol = 1.000e-07) r (rel) = 1.794e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 3.549e-07 (tol = 1.000e-07) r (rel) = 1.066e-12 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 227 linear solver iterations.
# Expected injected mass at t = 5.98 years : 1.0638226027397262 Mt
# Injected mass found at t = 5.98 years : 0.9476285401154714 Mt (cumulative)
# Relative difference = 10.922315649715769 %
# Iteration 66 : t = 5.98 years ------> t = 6.04 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 1.606e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.027e+02 (tol = 1.000e-07) r (rel) = 4.376e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.711e-01 (tol = 1.000e-07) r (rel) = 1.066e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.962e-05 (tol = 1.000e-07) r (rel) = 3.713e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 179 linear solver iterations.
# Expected injected mass at t = 6.04 years : 1.1311541095890412 Mt
# Injected mass found at t = 6.04 years : 1.0157722770023816 Mt (cumulative)
# Relative difference = 10.200363647052367 %
# Iteration 67 : t = 6.04 years ------> t = 6.17 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 3.050e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.967e+03 (tol = 1.000e-07) r (rel) = 6.450e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 4.025e+00 (tol = 1.000e-07) r (rel) = 1.320e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 3.885e-03 (tol = 1.000e-07) r (rel) = 1.274e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 6.998e-08 (tol = 1.000e-07) r (rel) = 2.295e-13 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 249 linear solver iterations.
# Expected injected mass at t = 6.17 years : 1.2658171232876712 Mt
# Injected mass found at t = 6.17 years : 1.1513247000390292 Mt (cumulative)
# Relative difference = 9.0449418910746 %
# Iteration 68 : t = 6.17 years ------> t = 6.23 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 1.489e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.833e+02 (tol = 1.000e-07) r (rel) = 3.917e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.269e-01 (tol = 1.000e-07) r (rel) = 8.521e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.922e-05 (tol = 1.000e-07) r (rel) = 1.290e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 214 linear solver iterations.
# Expected injected mass at t = 6.23 years : 1.3331486301369864 Mt
# Injected mass found at t = 6.23 years : 1.2196794302590785 Mt (cumulative)
# Relative difference = 8.511369048644513 %
# Iteration 69 : t = 6.23 years ------> t = 6.35 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.876e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.656e+03 (tol = 1.000e-07) r (rel) = 5.759e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.178e+00 (tol = 1.000e-07) r (rel) = 1.105e-05 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.990e-03 (tol = 1.000e-07) r (rel) = 1.040e-08 (tol = 1.000e-08)
# Newton iteration 4: r (abs) = 1.409e-07 (tol = 1.000e-07) r (rel) = 4.898e-13 (tol = 1.000e-08)
# Newton solver finished in 5 iterations and 239 linear solver iterations.
# Expected injected mass at t = 6.35 years : 1.4678116438356166 Mt
# Injected mass found at t = 6.35 years : 1.3554135676240073 Mt (cumulative)
# Relative difference = 7.657527223172584 %
# Iteration 70 : t = 6.35 years ------> t = 6.42 years (dt = 22.7 days)
#
# Newton iteration 0: r (abs) = 1.414e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.071e+02 (tol = 1.000e-07) r (rel) = 3.586e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.266e-02 (tol = 1.000e-07) r (rel) = 6.552e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.023e-05 (tol = 1.000e-07) r (rel) = 7.235e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 205 linear solver iterations.
# Expected injected mass at t = 6.42 years : 1.5351431506849316 Mt
# Injected mass found at t = 6.42 years : 1.4239816118907682 Mt (cumulative)
# Relative difference = 7.2411187676254665 %
# Iteration 71 : t = 6.42 years ------> t = 6.54 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.758e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.431e+03 (tol = 1.000e-07) r (rel) = 5.189e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.406e+00 (tol = 1.000e-07) r (rel) = 8.722e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.061e-03 (tol = 1.000e-07) r (rel) = 7.471e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 197 linear solver iterations.
# Expected injected mass at t = 6.54 years : 1.6698061643835618 Mt
# Injected mass found at t = 6.54 years : 1.5598250214687968 Mt (cumulative)
# Relative difference = 6.586461666068071 %
# Iteration 72 : t = 6.54 years ------> t = 6.67 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.699e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.310e+03 (tol = 1.000e-07) r (rel) = 4.855e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.049e+00 (tol = 1.000e-07) r (rel) = 7.592e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.514e-03 (tol = 1.000e-07) r (rel) = 5.608e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 186 linear solver iterations.
# Expected injected mass at t = 6.67 years : 1.804469178082192 Mt
# Injected mass found at t = 6.67 years : 1.6959718551821747 Mt (cumulative)
# Relative difference = 6.0127002565557435 %
# Iteration 73 : t = 6.67 years ------> t = 6.79 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.650e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.197e+03 (tol = 1.000e-07) r (rel) = 4.518e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.499e+00 (tol = 1.000e-07) r (rel) = 5.658e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.155e-03 (tol = 1.000e-07) r (rel) = 4.359e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 191 linear solver iterations.
# Expected injected mass at t = 6.79 years : 1.939132191780822 Mt
# Injected mass found at t = 6.79 years : 1.8322072684504547 Mt (cumulative)
# Relative difference = 5.514060556757181 %
# Iteration 74 : t = 6.79 years ------> t = 6.92 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.608e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.100e+03 (tol = 1.000e-07) r (rel) = 4.217e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.114e+00 (tol = 1.000e-07) r (rel) = 4.270e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 8.136e-04 (tol = 1.000e-07) r (rel) = 3.119e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 222 linear solver iterations.
# Expected injected mass at t = 6.92 years : 2.073795205479452 Mt
# Injected mass found at t = 6.92 years : 1.9686693182065371 Mt (cumulative)
# Relative difference = 5.069251148577639 %
# Iteration 75 : t = 6.92 years ------> t = 7.04 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.572e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 1.035e+03 (tol = 1.000e-07) r (rel) = 4.024e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.950e-01 (tol = 1.000e-07) r (rel) = 3.868e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 6.706e-04 (tol = 1.000e-07) r (rel) = 2.607e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 220 linear solver iterations.
# Expected injected mass at t = 7.04 years : 2.208458219178082 Mt
# Injected mass found at t = 7.04 years : 2.1054463033008193 Mt (cumulative)
# Relative difference = 4.664426747253593 %
# Iteration 76 : t = 7.04 years ------> t = 7.16 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.541e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 9.551e+02 (tol = 1.000e-07) r (rel) = 3.759e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.119e-01 (tol = 1.000e-07) r (rel) = 2.408e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 4.393e-04 (tol = 1.000e-07) r (rel) = 1.729e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 231 linear solver iterations.
# Expected injected mass at t = 7.16 years : 2.3431212328767126 Mt
# Injected mass found at t = 7.16 years : 2.2426133158628407 Mt (cumulative)
# Relative difference = 4.289488550725795 %
# Iteration 77 : t = 7.16 years ------> t = 7.29 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.513e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.887e+02 (tol = 1.000e-07) r (rel) = 3.536e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 4.884e-01 (tol = 1.000e-07) r (rel) = 1.943e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 3.198e-04 (tol = 1.000e-07) r (rel) = 1.272e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 232 linear solver iterations.
# Expected injected mass at t = 7.29 years : 2.477784246575342 Mt
# Injected mass found at t = 7.29 years : 2.380245709948003 Mt (cumulative)
# Relative difference = 3.936522591188147 %
# Iteration 78 : t = 7.29 years ------> t = 7.41 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.489e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.465e+02 (tol = 1.000e-07) r (rel) = 3.401e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 4.396e-01 (tol = 1.000e-07) r (rel) = 1.766e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.893e-04 (tol = 1.000e-07) r (rel) = 1.162e-09 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 233 linear solver iterations.
# Expected injected mass at t = 7.41 years : 2.6124472602739726 Mt
# Injected mass found at t = 7.41 years : 2.5181771854753547 Mt (cumulative)
# Relative difference = 3.60849676210235 %
# Iteration 79 : t = 7.41 years ------> t = 7.54 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.467e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 8.131e+02 (tol = 1.000e-07) r (rel) = 3.296e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 3.925e-01 (tol = 1.000e-07) r (rel) = 1.591e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.434e-04 (tol = 1.000e-07) r (rel) = 9.864e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 238 linear solver iterations.
# Expected injected mass at t = 7.54 years : 2.747110273972603 Mt
# Injected mass found at t = 7.54 years : 2.656412851285684 Mt (cumulative)
# Relative difference = 3.3015574054754264 %
# Iteration 80 : t = 7.54 years ------> t = 7.66 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.448e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.801e+02 (tol = 1.000e-07) r (rel) = 3.187e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 2.774e-01 (tol = 1.000e-07) r (rel) = 1.133e-06 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.202e-04 (tol = 1.000e-07) r (rel) = 4.909e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 249 linear solver iterations.
# Expected injected mass at t = 7.66 years : 2.8817732876712334 Mt
# Injected mass found at t = 7.66 years : 2.7949829918045292 Mt (cumulative)
# Relative difference = 3.0116975626781315 %
# Iteration 81 : t = 7.66 years ------> t = 7.79 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.430e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.455e+02 (tol = 1.000e-07) r (rel) = 3.067e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.788e-01 (tol = 1.000e-07) r (rel) = 7.359e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 6.042e-05 (tol = 1.000e-07) r (rel) = 2.486e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 248 linear solver iterations.
# Expected injected mass at t = 7.79 years : 3.0164363013698634 Mt
# Injected mass found at t = 7.79 years : 2.9340329844416297 Mt (cumulative)
# Relative difference = 2.7318102785996694 %
# Iteration 82 : t = 7.79 years ------> t = 7.91 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.415e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.269e+02 (tol = 1.000e-07) r (rel) = 3.011e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.520e-01 (tol = 1.000e-07) r (rel) = 6.297e-07 (tol = 1.000e-08)
# Expected injected mass at t = 7.91 years : 3.151099315068493 Mt
# Injected mass found at t = 7.91 years : 3.0735643030791624 Mt (cumulative)
# Relative difference = 2.460570240314544 %
# Iteration 83 : t = 7.91 years ------> t = 8.04 years (dt = 45.5 days)
#
# Newton iteration 3: r (abs) = 4.538e-05 (tol = 1.000e-07) r (rel) = 1.879e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 249 linear solver iterations.
# Newton iteration 0: r (abs) = 2.400e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 7.036e+02 (tol = 1.000e-07) r (rel) = 2.931e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.125e-01 (tol = 1.000e-07) r (rel) = 4.688e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 3.102e-05 (tol = 1.000e-07) r (rel) = 1.292e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 246 linear solver iterations.
# Expected injected mass at t = 8.04 years : 3.2857623287671234 Mt
# Injected mass found at t = 8.04 years : 3.213527927337664 Mt (cumulative)
# Relative difference = 2.1984061597225506 %
# Iteration 84 : t = 8.04 years ------> t = 8.16 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.387e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.827e+02 (tol = 1.000e-07) r (rel) = 2.860e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.188e-01 (tol = 1.000e-07) r (rel) = 4.978e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.207e-05 (tol = 1.000e-07) r (rel) = 5.056e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 241 linear solver iterations.
# Expected injected mass at t = 8.16 years : 3.420425342465754 Mt
# Injected mass found at t = 8.16 years : 3.3538367587727635 Mt (cumulative)
# Relative difference = 1.946792489994452 %
# Iteration 85 : t = 8.16 years ------> t = 8.29 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.375e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.694e+02 (tol = 1.000e-07) r (rel) = 2.818e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.524e-02 (tol = 1.000e-07) r (rel) = 4.010e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 3.907e-05 (tol = 1.000e-07) r (rel) = 1.645e-10 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 242 linear solver iterations.
# Expected injected mass at t = 8.29 years : 3.5550883561643842 Mt
# Injected mass found at t = 8.29 years : 3.494453937381753 Mt (cumulative)
# Relative difference = 1.7055671394915743 %
# Iteration 86 : t = 8.29 years ------> t = 8.41 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.364e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.529e+02 (tol = 1.000e-07) r (rel) = 2.762e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.659e-02 (tol = 1.000e-07) r (rel) = 4.086e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.235e-05 (tol = 1.000e-07) r (rel) = 9.455e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 249 linear solver iterations.
# Expected injected mass at t = 8.41 years : 3.6897513698630147 Mt
# Injected mass found at t = 8.41 years : 3.6353579181264584 Mt (cumulative)
# Relative difference = 1.4741766120294297 %
# Iteration 87 : t = 8.41 years ------> t = 8.54 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.354e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.458e+02 (tol = 1.000e-07) r (rel) = 2.743e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 1.011e-01 (tol = 1.000e-07) r (rel) = 4.295e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.276e-05 (tol = 1.000e-07) r (rel) = 5.420e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 251 linear solver iterations.
# Expected injected mass at t = 8.54 years : 3.8244143835616438 Mt
# Injected mass found at t = 8.54 years : 3.7764714461396176 Mt (cumulative)
# Relative difference = 1.253602058084964 %
# Iteration 88 : t = 8.54 years ------> t = 8.66 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.345e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.318e+02 (tol = 1.000e-07) r (rel) = 2.694e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.117e-02 (tol = 1.000e-07) r (rel) = 3.888e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.018e-05 (tol = 1.000e-07) r (rel) = 4.342e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 225 linear solver iterations.
# Expected injected mass at t = 8.66 years : 3.959077397260274 Mt
# Injected mass found at t = 8.66 years : 3.9176710841407636 Mt (cumulative)
# Relative difference = 1.0458576320878263 %
# Iteration 89 : t = 8.66 years ------> t = 8.79 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.337e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.300e+02 (tol = 1.000e-07) r (rel) = 2.696e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 9.342e-02 (tol = 1.000e-07) r (rel) = 3.998e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 9.290e-06 (tol = 1.000e-07) r (rel) = 3.975e-11 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 227 linear solver iterations.
# Expected injected mass at t = 8.79 years : 4.093740410958905 Mt
# Injected mass found at t = 8.79 years : 4.058831766751009 Mt (cumulative)
# Relative difference = 0.8527322375997552 %
# Iteration 90 : t = 8.79 years ------> t = 8.91 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.329e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.170e+02 (tol = 1.000e-07) r (rel) = 2.649e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.350e-02 (tol = 1.000e-07) r (rel) = 3.585e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.684e-06 (tol = 1.000e-07) r (rel) = 7.231e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 232 linear solver iterations.
# Expected injected mass at t = 8.91 years : 4.228403424657535 Mt
# Injected mass found at t = 8.91 years : 4.199817125609128 Mt (cumulative)
# Relative difference = 0.6760542024374567 %
# Iteration 91 : t = 8.91 years ------> t = 9.03 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.322e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.046e+02 (tol = 1.000e-07) r (rel) = 2.604e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 8.043e-02 (tol = 1.000e-07) r (rel) = 3.464e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.670e-06 (tol = 1.000e-07) r (rel) = 7.195e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 234 linear solver iterations.
# Expected injected mass at t = 9.03 years : 4.363066438356165 Mt
# Injected mass found at t = 9.03 years : 4.340608128743739 Mt (cumulative)
# Relative difference = 0.5147368239684023 %
# Iteration 92 : t = 9.03 years ------> t = 9.16 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.315e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.066e+02 (tol = 1.000e-07) r (rel) = 2.620e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.971e-02 (tol = 1.000e-07) r (rel) = 3.443e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.518e-06 (tol = 1.000e-07) r (rel) = 6.555e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 234 linear solver iterations.
# Expected injected mass at t = 9.16 years : 4.497729452054795 Mt
# Injected mass found at t = 9.16 years : 4.481258939744845 Mt (cumulative)
# Relative difference = 0.3661961548715496 %
# Iteration 93 : t = 9.16 years ------> t = 9.28 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.309e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.147e+02 (tol = 1.000e-07) r (rel) = 2.662e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.951e-02 (tol = 1.000e-07) r (rel) = 3.444e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 4.737e-07 (tol = 1.000e-07) r (rel) = 2.052e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 233 linear solver iterations.
# Expected injected mass at t = 9.28 years : 4.632392465753425 Mt
# Injected mass found at t = 9.28 years : 4.621786726248897 Mt (cumulative)
# Relative difference = 0.22894734379555856 %
# Iteration 94 : t = 9.28 years ------> t = 9.41 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.303e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.048e+02 (tol = 1.000e-07) r (rel) = 2.626e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.557e-02 (tol = 1.000e-07) r (rel) = 3.282e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 6.622e-07 (tol = 1.000e-07) r (rel) = 2.876e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 236 linear solver iterations.
# Expected injected mass at t = 9.41 years : 4.767055479452055 Mt
# Injected mass found at t = 9.41 years : 4.762568549686956 Mt (cumulative)
# Relative difference = 0.09412371608509826 %
# Iteration 95 : t = 9.41 years ------> t = 9.53 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.297e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.953e+02 (tol = 1.000e-07) r (rel) = 2.591e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 7.001e-02 (tol = 1.000e-07) r (rel) = 3.047e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.376e-06 (tol = 1.000e-07) r (rel) = 5.990e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 222 linear solver iterations.
# Expected injected mass at t = 9.53 years : 4.9017184931506845 Mt
# Injected mass found at t = 9.53 years : 4.90351413169261 Mt (cumulative)
# Relative difference = 0.03663283692106205 %
# Iteration 96 : t = 9.53 years ------> t = 9.66 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.292e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 5.859e+02 (tol = 1.000e-07) r (rel) = 2.556e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.247e-02 (tol = 1.000e-07) r (rel) = 2.726e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.661e-06 (tol = 1.000e-07) r (rel) = 7.247e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 222 linear solver iterations.
# Expected injected mass at t = 9.66 years : 5.036381506849316 Mt
# Injected mass found at t = 9.66 years : 5.044467056974067 Mt (cumulative)
# Relative difference = 0.1605428443765629 %
# Iteration 97 : t = 9.66 years ------> t = 9.78 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.287e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.210e+02 (tol = 1.000e-07) r (rel) = 2.715e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.400e-02 (tol = 1.000e-07) r (rel) = 2.798e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 5.615e-07 (tol = 1.000e-07) r (rel) = 2.455e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 215 linear solver iterations.
# Expected injected mass at t = 9.78 years : 5.171044520547945 Mt
# Injected mass found at t = 9.78 years : 5.185596313068087 Mt (cumulative)
# Relative difference = 0.2814091517162114 %
# Iteration 98 : t = 9.78 years ------> t = 9.91 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.283e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.122e+02 (tol = 1.000e-07) r (rel) = 2.682e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 6.047e-02 (tol = 1.000e-07) r (rel) = 2.649e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 1.269e-06 (tol = 1.000e-07) r (rel) = 5.560e-12 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 215 linear solver iterations.
# Expected injected mass at t = 9.91 years : 5.305707534246576 Mt
# Injected mass found at t = 9.91 years : 5.326962358929566 Mt (cumulative)
# Relative difference = 0.40060302128975744 %
# Iteration 99 : t = 9.91 years ------> t = 10.03 years (dt = 45.5 days)
#
# Newton iteration 0: r (abs) = 2.278e+05 (tol = 1.000e-07) r (rel) = 1.000e+00 (tol = 1.000e-08)
# Newton iteration 1: r (abs) = 6.021e+02 (tol = 1.000e-07) r (rel) = 2.643e-03 (tol = 1.000e-08)
# Newton iteration 2: r (abs) = 5.775e-02 (tol = 1.000e-07) r (rel) = 2.535e-07 (tol = 1.000e-08)
# Newton iteration 3: r (abs) = 2.125e-07 (tol = 1.000e-07) r (rel) = 9.327e-13 (tol = 1.000e-08)
# Newton solver finished in 4 iterations and 222 linear solver iterations.
# Expected injected mass at t = 10.03 years : 5.4 Mt
# Injected mass found at t = 10.03 years : 5.468449260591608 Mt (cumulative)
# Relative difference = 1.2675788998445934 %

# %% [markdown]
# # Loop data

# %%
print(Fore.BLUE + 'Number of iteration = ' + str(Nt))
print(Fore.GREEN + 'loop time = ' + day_format(timef - time0))
print(Style.RESET_ALL)

Mass_found = assemble(h*rho_g(p)*phi*dx)*sg # we consider the density as constant
Expected_injected_mass = injected_mass(t, Sources_g)

p_min, p_max, h_min, h_max = min_max_pressure_h_total(output_folder, Nt, H, g, sg, 50, rho_g, rho_w, List_t)

###########################################################################################################################
# Plot loop data
print('Minimum and maximum pressure in the reservoir during operation : ' + str(p_min) + ' / ' + str(p_max) + ' bar')
print('Minimum and maximum value of h during operation : ' + str(h_min) + ' / ' + str(h_max) + ' m')

#Plot relative error (for mass) curve
plt.figure(figsize=(14, 5))
plt.xlabel('Time (year)') ; plt.ylabel('Error (%)')
plt.plot(np.array(List_t)/(24*3600*365), 100*np.array(List_err), color='black')
plt.title('Relative error between injected mass and mass found at each step')
plt.savefig(os.path.join(figures_output, 'QUEST_Model_accuracy.png'), dpi=300, bbox_inches='tight')
# Out:
# Number of iteration = 99
# loop time = 28 s
# 100%|██████████| 99/99 [00:02<00:00, 48.60it/s]
# Minimum and maximum pressure in the reservoir during operation : 171.92540408769747 / 240.36256184154223 bar
# Minimum and maximum value of h during operation : -0.08711234540409558 / 12.857288813629228 m

# %% [markdown]
# # Save and plot results
# ### Top views

# %%
Nx = 1e3 ; Ny = 1e3 ; Nz = 1e3

plot_p(output_folder, figures_output, Nt, AOI, p_min, p_max, List_t, ME1, 320e3, 410e3, 5950e3, 6052e3)
# plot_h(output_folder, figures_output, 258, AOI, h_min, h_max, List_t, ME1, 320e3, 410e3, 5950e3, 6052e3)
# plot_h(output_folder, figures_output, Nt, AOI, h_min, h_max, List_t, ME1, 320e3, 410e3, 5950e3, 6052e3)
# Out:
# Maximum pressure at the interface at t = 10.03 years : 240.40522883914994 bar
# After interpolation : 240.4052288388957 bar

# %%
def export_p(folder, iteration, Nx, Ny, Nz, List_t, AOI, Outline, phi0, k0):
    points_init, pressure_int, h = extract_points_p_h(folder, iteration)
    points = [] ; P = []

    for i in tqdm(range(len(points_init))):
        points.append([points_init[i][0], points_init[i][1]])

    X = np.linspace(Outline[0][0], Outline[1][0], int(Nx)) ; Y = np.linspace(Outline[0][1], Outline[2][1], int(Ny))
    grid_x, grid_y = np.meshgrid(X, Y)

    grid_z = np.array(griddata(points, pressure_int, (grid_x, grid_y), method='linear')) #interpolate the data
    pkl.dump(X, open('Figures data/QUEST/p_no_topo_Porosity_permeability_variation_data_X'+str(phi0)+'-'+str(k0)+'.p', 'wb'))
    pkl.dump(Y, open('Figures data/QUEST/p_no_topo_Porosity_permeability_variation_data_Y'+str(phi0)+'-'+str(k0)+'.p', 'wb'))
    pkl.dump(grid_z, open('Figures data/QUEST/p_no_topo_Porosity_permeability_variation_data_P'+str(phi0)+'-'+str(k0)+'.p', 'wb'))

def export_h(folder, iteration, Nx, Ny, Nz, List_t, AOI, Outline, phi0, k0):
    points_init, pressure_int, h = extract_points_p_h(folder, iteration)
    points = [] ; h_data = []

    for i in tqdm(range(len(points_init))):
        points.append([points_init[i][0], points_init[i][1]])
        h_data.append(h[i])
    X = np.linspace(Outline[0][0], Outline[1][0], int(Nx)) ; Y = np.linspace(Outline[0][1], Outline[2][1], int(Ny))
    grid_x, grid_y = np.meshgrid(X, Y)

    grid_z = np.array(griddata(points, h_data, (grid_x, grid_y), method='linear')) #interpolate the data
    pkl.dump(X, open('Figures data/QUEST/h_no_topo_Porosity_permeability_variation_data_X'+str(phi0)+'-'+str(k0)+'.p', 'wb'))
    pkl.dump(Y, open( 'Figures data/QUEST/h_no_topo_Porosity_permeability_variation_data_Y'+str(phi0)+'-'+str(k0)+'.p', 'wb'))
    pkl.dump(grid_z, open( 'Figures data/QUEST/h_no_topo_Porosity_permeability_variation_data_P'+str(phi0)+'-'+str(k0)+'.p', 'wb'))

# %%
folder = 'QUEST - Topo/Outputs - Diffusion model/'

# export_p(folder, Nt, Nx, Ny, Nz, List_t, AOI, Outline, phi0, k0)
# export_h(folder, Nt, Nx, Ny, Nz, List_t, AOI, Outline, phi0, k0)
# Out:
# 100%|██████████| 3002/3002 [00:00<00:00, 79518.14it/s]
# 100%|██████████| 3002/3002 [00:00<00:00, 134702.33it/s]

# %% [markdown]
# # Export data for mechanical model

# %%
# xmax = Outline[1][0]
# xmin = Outline[0][0]
ymax = Outline[2][1]
ymin = Outline[0][1]

XMesh = [] ; YMesh = []
for i in range(54):
    XMesh_tamp = [xmin+(xmax-xmin)*j/49 for j in range(50)]
    XMesh.append(XMesh_tamp)

for i in range(54):
    YMesh_tamp = [ymin+(ymax-ymin)*i/53 for j in range(50)]
    YMesh.append(YMesh_tamp)

X_, Y_ = np.meshgrid(np.array(XMesh)[0], np.array(YMesh)[:,0])
Thick = griddata(H_points, H_field, (X_, Y_), method='linear')
Depth = griddata(depth_points, depth_field, (X_, Y_), method='linear')

# Export RES
dRES = {'Depth':Depth, 'Thickness': Thick}
with open(output_folder + 'RES.p', 'wb') as handle: pickle.dump(dRES, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# Export X and Y coordinates
pickle.dump(np.array(XMesh), open(output_folder + 'X.p', 'wb')) ; pickle.dump(np.array(YMesh), open(output_folder + 'Y.p', 'wb'))

# Export Outline
Xcoordinates1 = np.linspace(xmin, xmin, 1000)
Xcoordinates2 = np.linspace(xmin, xmax, 1000)
Xcoordinates3 = np.linspace(xmax, xmax, 1000)
Xcoordinates4 = np.linspace(xmax, xmin, 1000)

Ycoordinates1 = np.linspace(ymin, ymax, 1000)
Ycoordinates2 = np.linspace(ymax, ymax, 1000)
Ycoordinates3 = np.linspace(ymax, ymin, 1000)
Ycoordinates4 = np.linspace(ymin, ymin, 1000)

dOutline = {'X': np.concatenate((Xcoordinates1,Xcoordinates2,Xcoordinates3,Xcoordinates4)), 'Y':np.concatenate((Ycoordinates1,Ycoordinates2,Ycoordinates3,Ycoordinates4))}
dfOutline = pd.DataFrame(data=dOutline)

with open(output_folder + 'Outline.p', 'wb') as handle: pickle.dump(dfOutline, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Export MESH
np.save(output_folder +'MESH.npy', np.array(mesh.coordinates()))

#Export thickness and depth

pickle.dump(np.array(H_points), open(output_folder + 'H_points.npy', 'wb'))
pickle.dump(np.array(H_field), open(output_folder + 'H_field.npy', 'wb'))
pickle.dump(np.array(depth_points), open(output_folder + 'Depth_points.npy', 'wb'))
pickle.dump(np.array(depth_field), open(output_folder + 'Depth_field.npy', 'wb'))
    
# Export data for mechanical model in folder 'output/'
# extract_pressure_list(folder_input, folder_output, Nt)
